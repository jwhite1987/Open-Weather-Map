# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
# Import API key
from api_keys import weather_api_key
import seaborn as sns

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Making sure the units are imperial and settings up the url for the api
units = 'imperial'
url = "http://api.openweathermap.org/data/2.5/weather?"    
# Creating lists for the data that will be stored from the .json request
lat = []
long = []
maxtemp = []
humidity = []
clouds = []
wind_speed = []
country = []
new_city = []
counter = 1

# %%
# Creating a for loop which will query the api and grab info for the set of lats/lngs from above.
# Also for any lat/lng that it doesn't find a city, it will skip over those and go to the next.
for city in cities:
    query_url = f'{url}appid={weather_api_key}&units={units}&q={city}'
    data = requests.get(query_url)
    data2 = data.json()
    if counter == 1:
        print('Beginning Data Retrieval:\n---------------------------')
    try: 
        new_city.append(data2['name'])
        lat.append(data2['coord']['lat'])
        long.append(data2['coord']['lon'])
        maxtemp.append(data2['main']['temp_max'])
        humidity.append(data2['main']['humidity'])
        clouds.append(data2['clouds']['all'])
        wind_speed.append(data2['wind']['speed'])
        country.append(data2['sys']['country'])
        current_city = data2['name']
        print(f'Processing Record  {counter} of Set 1 | {current_city}')
        counter += 1
    except:
        pass
# Out:
# Beginning Data Retrieval:
# ---------------------------
# Processing Record  1 of Set 1 | Saskylakh
# Processing Record  2 of Set 1 | Atuona
# Processing Record  3 of Set 1 | Torbay
# Processing Record  4 of Set 1 | Yellowknife
# Processing Record  5 of Set 1 | Los Llanos de Aridane
# Processing Record  6 of Set 1 | Port Hardy
# Processing Record  7 of Set 1 | Aripuanã
# Processing Record  8 of Set 1 | Albany
# Processing Record  9 of Set 1 | Carnarvon
# Processing Record  10 of Set 1 | Ciudad Bolivar
# Processing Record  11 of Set 1 | Castro
# Processing Record  12 of Set 1 | Maniitsoq
# Processing Record  13 of Set 1 | Chui
# Processing Record  14 of Set 1 | Mar del Plata
# Processing Record  15 of Set 1 | Byron Bay
# Processing Record  16 of Set 1 | Bredasdorp
# Processing Record  17 of Set 1 | Macklin
# Processing Record  18 of Set 1 | Nishihara
# Processing Record  19 of Set 1 | Upernavik
# Processing Record  20 of Set 1 | Chokurdakh
# Processing Record  21 of Set 1 | Ushuaia
# Processing Record  22 of Set 1 | Sitka
# Processing Record  23 of Set 1 | Phalaborwa
# Processing Record  24 of Set 1 | Tuatapere
# Processing Record  25 of Set 1 | Jalu
# Processing Record  26 of Set 1 | Rikitea
# Processing Record  27 of Set 1 | Kassala
# Processing Record  28 of Set 1 | Hermanus
# Processing Record  29 of Set 1 | Aksu
# Processing Record  30 of Set 1 | Esperance
# Processing Record  31 of Set 1 | Ahipara
# Processing Record  32 of Set 1 | Durban
# Processing Record  33 of Set 1 | Steinbach am Taunus
# Processing Record  34 of Set 1 | Meulaboh
# Processing Record  35 of Set 1 | Saint Paul Harbor
# Processing Record  36 of Set 1 | Nikolskoye
# Processing Record  37 of Set 1 | Cape Town
# Processing Record  38 of Set 1 | Coyhaique
# Processing Record  39 of Set 1 | Le Port
# Processing Record  40 of Set 1 | Qasigiannguit
# Processing Record  41 of Set 1 | Tiksi
# Processing Record  42 of Set 1 | Santa Cruz de la Sierra
# Processing Record  43 of Set 1 | Bac Lieu
# Processing Record  44 of Set 1 | Mataura
# Processing Record  45 of Set 1 | Cidreira
# Processing Record  46 of Set 1 | Lieksa
# Processing Record  47 of Set 1 | Okhotsk
# Processing Record  48 of Set 1 | New Norfolk
# Processing Record  49 of Set 1 | Ancud
# Processing Record  50 of Set 1 | Ribeira Grande
# Processing Record  51 of Set 1 | Hilo
# Processing Record  52 of Set 1 | Hong Kong
# Processing Record  53 of Set 1 | Begoro
# Processing Record  54 of Set 1 | Saint George
# Processing Record  55 of Set 1 | Faya
# Processing Record  56 of Set 1 | Lima
# Processing Record  57 of Set 1 | Tasiilaq
# Processing Record  58 of Set 1 | Lázaro Cárdenas
# Processing Record  59 of Set 1 | Barrow
# Processing Record  60 of Set 1 | Mahébourg
# Processing Record  61 of Set 1 | Grindavik
# Processing Record  62 of Set 1 | São Filipe
# Processing Record  63 of Set 1 | Busselton
# Processing Record  64 of Set 1 | Maţāy
# Processing Record  65 of Set 1 | Saint-Philippe
# Processing Record  66 of Set 1 | Avarua
# Processing Record  67 of Set 1 | Punta Arenas
# Processing Record  68 of Set 1 | Verkhoyansk
# Processing Record  69 of Set 1 | Purpe
# Processing Record  70 of Set 1 | Hobart
# Processing Record  71 of Set 1 | Port Elizabeth
# Processing Record  72 of Set 1 | Butaritari
# Processing Record  73 of Set 1 | Vaini
# Processing Record  74 of Set 1 | Huarmey
# Processing Record  75 of Set 1 | Gorontalo
# Processing Record  76 of Set 1 | Dwārka
# Processing Record  77 of Set 1 | Carutapera
# Processing Record  78 of Set 1 | Ialibu
# Processing Record  79 of Set 1 | Gornopravdinsk
# Processing Record  80 of Set 1 | Viedma
# Processing Record  81 of Set 1 | Kapaa
# Processing Record  82 of Set 1 | Constitución
# Processing Record  83 of Set 1 | Pyskowice
# Processing Record  84 of Set 1 | Port Alfred
# Processing Record  85 of Set 1 | ‘Āhuimanu
# Processing Record  86 of Set 1 | Jamestown
# Processing Record  87 of Set 1 | Novikovo
# Processing Record  88 of Set 1 | Korla
# Processing Record  89 of Set 1 | Labis
# Processing Record  90 of Set 1 | Paamiut
# Processing Record  91 of Set 1 | Cabano
# Processing Record  92 of Set 1 | Coquimbo
# Processing Record  93 of Set 1 | Sørland
# Processing Record  94 of Set 1 | Cabo San Lucas
# Processing Record  95 of Set 1 | Makakilo City
# Processing Record  96 of Set 1 | Lompoc
# Processing Record  97 of Set 1 | Ilulissat
# Processing Record  98 of Set 1 | Ketchikan
# Processing Record  99 of Set 1 | Santa Isabel Rio Negro
# Processing Record  100 of Set 1 | Udupi
# Processing Record  101 of Set 1 | Qaanaaq
# Processing Record  102 of Set 1 | Muros
# Processing Record  103 of Set 1 | Dubbo
# Processing Record  104 of Set 1 | Salto
# Processing Record  105 of Set 1 | Dores do Indaiá
# Processing Record  106 of Set 1 | Khovd
# Processing Record  107 of Set 1 | Kieta
# Processing Record  108 of Set 1 | Yulara
# Processing Record  109 of Set 1 | Saldanha
# Processing Record  110 of Set 1 | Belmonte
# Processing Record  111 of Set 1 | Bluff
# Processing Record  112 of Set 1 | Chipinge
# Processing Record  113 of Set 1 | Conde
# Processing Record  114 of Set 1 | Opuwo
# Processing Record  115 of Set 1 | Safakulevo
# Processing Record  116 of Set 1 | Nara
# Processing Record  117 of Set 1 | Bethel
# Processing Record  118 of Set 1 | Pangoa
# Processing Record  119 of Set 1 | Chakwal
# Processing Record  120 of Set 1 | Menemen
# Processing Record  121 of Set 1 | Rudolstadt
# Processing Record  122 of Set 1 | Beruwala
# Processing Record  123 of Set 1 | San Lorenzo
# Processing Record  124 of Set 1 | Alindao
# Processing Record  125 of Set 1 | Dikson
# Processing Record  126 of Set 1 | Katherine
# Processing Record  127 of Set 1 | Ibrā’
# Processing Record  128 of Set 1 | Ionia
# Processing Record  129 of Set 1 | Narsaq
# Processing Record  130 of Set 1 | East London
# Processing Record  131 of Set 1 | Kaitangata
# Processing Record  132 of Set 1 | Sechura
# Processing Record  133 of Set 1 | Clyde River
# Processing Record  134 of Set 1 | Salalah
# Processing Record  135 of Set 1 | Puerto Madryn
# Processing Record  136 of Set 1 | Itarema
# Processing Record  137 of Set 1 | Charters Towers
# Processing Record  138 of Set 1 | Tuktoyaktuk
# Processing Record  139 of Set 1 | Eirunepé
# Processing Record  140 of Set 1 | Brownsville
# Processing Record  141 of Set 1 | Nemuro
# Processing Record  142 of Set 1 | Mandera
# Processing Record  143 of Set 1 | Ponta do Sol
# Processing Record  144 of Set 1 | Havre-St-Pierre
# Processing Record  145 of Set 1 | Quatre Cocos
# Processing Record  146 of Set 1 | Isangel
# Processing Record  147 of Set 1 | Ust-Kuyga
# Processing Record  148 of Set 1 | Zavetnoye
# Processing Record  149 of Set 1 | Al Bardīyah
# Processing Record  150 of Set 1 | Puerto Ayora
# Processing Record  151 of Set 1 | Plettenberg Bay
# Processing Record  152 of Set 1 | Kumluca
# Processing Record  153 of Set 1 | Esfarāyen
# Processing Record  154 of Set 1 | La Serena
# Processing Record  155 of Set 1 | Acapulco de Juárez
# Processing Record  156 of Set 1 | Husavik
# Processing Record  157 of Set 1 | Burnie
# Processing Record  158 of Set 1 | George Town
# Processing Record  159 of Set 1 | Khatanga
# Processing Record  160 of Set 1 | Lorengau
# Processing Record  161 of Set 1 | Karpathos
# Processing Record  162 of Set 1 | Upata
# Processing Record  163 of Set 1 | San Cristobal
# Processing Record  164 of Set 1 | Akçakoca
# Processing Record  165 of Set 1 | Iqaluit
# Processing Record  166 of Set 1 | Alofi
# Processing Record  167 of Set 1 | Assiut
# Processing Record  168 of Set 1 | Okato
# Processing Record  169 of Set 1 | Sovetskiy
# Processing Record  170 of Set 1 | Kerema
# Processing Record  171 of Set 1 | Katsuura
# Processing Record  172 of Set 1 | Nong Chik
# Processing Record  173 of Set 1 | Bambous Virieux
# Processing Record  174 of Set 1 | Taoudenni
# Processing Record  175 of Set 1 | Nālūt
# Processing Record  176 of Set 1 | Shelburne
# Processing Record  177 of Set 1 | Coahuayana Viejo
# Processing Record  178 of Set 1 | Sipe Sipe
# Processing Record  179 of Set 1 | La Ronge
# Processing Record  180 of Set 1 | Shirakawa
# Processing Record  181 of Set 1 | Provideniya
# Processing Record  182 of Set 1 | Marrakesh
# Processing Record  183 of Set 1 | Sioux Lookout
# Processing Record  184 of Set 1 | Camacha
# Processing Record  185 of Set 1 | Faanui
# Processing Record  186 of Set 1 | Arraial do Cabo
# Processing Record  187 of Set 1 | Shangzhi
# Processing Record  188 of Set 1 | Bandarbeyla
# Processing Record  189 of Set 1 | Havelock
# Processing Record  190 of Set 1 | Adlay
# Processing Record  191 of Set 1 | Taltal
# Processing Record  192 of Set 1 | Poum
# Processing Record  193 of Set 1 | Mehamn
# Processing Record  194 of Set 1 | Tatebayashi
# Processing Record  195 of Set 1 | Kisangani
# Processing Record  196 of Set 1 | Ouadda
# Processing Record  197 of Set 1 | Cherskiy
# Processing Record  198 of Set 1 | Bubaque
# Processing Record  199 of Set 1 | Hamilton
# Processing Record  200 of Set 1 | Rock Sound
# Processing Record  201 of Set 1 | Simao
# Processing Record  202 of Set 1 | Thompson
# Processing Record  203 of Set 1 | Barra Velha
# Processing Record  204 of Set 1 | Xining
# Processing Record  205 of Set 1 | Hobyo
# Processing Record  206 of Set 1 | Henties Bay
# Processing Record  207 of Set 1 | Jumla
# Processing Record  208 of Set 1 | Hithadhoo
# Processing Record  209 of Set 1 | Kysyl-Syr
# Processing Record  210 of Set 1 | Monrovia
# Processing Record  211 of Set 1 | Tongliao
# Processing Record  212 of Set 1 | Béboto
# Processing Record  213 of Set 1 | Tonota
# Processing Record  214 of Set 1 | São João da Barra
# Processing Record  215 of Set 1 | Kitsuki
# Processing Record  216 of Set 1 | Jiaocheng
# Processing Record  217 of Set 1 | Mahibadhoo
# Processing Record  218 of Set 1 | Samarai
# Processing Record  219 of Set 1 | Campbell River
# Processing Record  220 of Set 1 | Kahului
# Processing Record  221 of Set 1 | Virginia Beach
# Processing Record  222 of Set 1 | Srednekolymsk
# Processing Record  223 of Set 1 | Bengkulu
# Processing Record  224 of Set 1 | Xiongzhou
# Processing Record  225 of Set 1 | Mount Gambier
# Processing Record  226 of Set 1 | Tyrma
# Processing Record  227 of Set 1 | Zaozyornoye
# Processing Record  228 of Set 1 | Norman Wells
# Processing Record  229 of Set 1 | Dicabisagan
# Processing Record  230 of Set 1 | Vianópolis
# Processing Record  231 of Set 1 | Urengoy
# Processing Record  232 of Set 1 | Sembabule
# Processing Record  233 of Set 1 | Airai
# Processing Record  234 of Set 1 | Cantaura
# Processing Record  235 of Set 1 | Damietta
# Processing Record  236 of Set 1 | Phalia
# Processing Record  237 of Set 1 | Sydney
# Processing Record  238 of Set 1 | Hanzhong
# Processing Record  239 of Set 1 | Oussouye
# Processing Record  240 of Set 1 | Batagay-Alyta
# Processing Record  241 of Set 1 | Mergen
# Processing Record  242 of Set 1 | Balkhash
# Processing Record  243 of Set 1 | Gizo Government Station
# Processing Record  244 of Set 1 | Cayenne
# Processing Record  245 of Set 1 | Kabala
# Processing Record  246 of Set 1 | Nouadhibou
# Processing Record  247 of Set 1 | Vardø
# Processing Record  248 of Set 1 | Souillac
# Processing Record  249 of Set 1 | Beyneu
# Processing Record  250 of Set 1 | Puerto Baquerizo Moreno
# Processing Record  251 of Set 1 | Haicheng
# Processing Record  252 of Set 1 | Malanville
# Processing Record  253 of Set 1 | Vila Franca do Campo
# Processing Record  254 of Set 1 | Manzhouli
# Processing Record  255 of Set 1 | Olafsvik
# Processing Record  256 of Set 1 | Koindu
# Processing Record  257 of Set 1 | Broome
# Processing Record  258 of Set 1 | Massakory
# Processing Record  259 of Set 1 | Ilebo
# Processing Record  260 of Set 1 | Touros
# Processing Record  261 of Set 1 | Tevaitoa
# Processing Record  262 of Set 1 | Vlădeni
# Processing Record  263 of Set 1 | Mitú
# Processing Record  264 of Set 1 | Hasaki
# Processing Record  265 of Set 1 | Padang
# Processing Record  266 of Set 1 | Vasai
# Processing Record  267 of Set 1 | Pangnirtung
# Processing Record  268 of Set 1 | Prainha
# Processing Record  269 of Set 1 | Solnechnyy
# Processing Record  270 of Set 1 | Bay Roberts
# Processing Record  271 of Set 1 | Buala
# Processing Record  272 of Set 1 | Ous
# Processing Record  273 of Set 1 | Mahajanga
# Processing Record  274 of Set 1 | Margate
# Processing Record  275 of Set 1 | Morón
# Processing Record  276 of Set 1 | Lebu
# Processing Record  277 of Set 1 | Ruy Barbosa
# Processing Record  278 of Set 1 | Codrington
# Processing Record  279 of Set 1 | Graaff-Reinet
# Processing Record  280 of Set 1 | Whitehorse
# Processing Record  281 of Set 1 | Flinders
# Processing Record  282 of Set 1 | Cleburne
# Processing Record  283 of Set 1 | Castel San Giovanni
# Processing Record  284 of Set 1 | Oranjemund
# Processing Record  285 of Set 1 | Flin Flon
# Processing Record  286 of Set 1 | Katobu
# Processing Record  287 of Set 1 | Dolores
# Processing Record  288 of Set 1 | Cockburn Town
# Processing Record  289 of Set 1 | Broadstairs
# Processing Record  290 of Set 1 | Puntarenas
# Processing Record  291 of Set 1 | Nicoya
# Processing Record  292 of Set 1 | Kudahuvadhoo
# Processing Record  293 of Set 1 | Calabozo
# Processing Record  294 of Set 1 | Bilma
# Processing Record  295 of Set 1 | Sembakung
# Processing Record  296 of Set 1 | Tomatlán
# Processing Record  297 of Set 1 | Ust-Tsilma
# Processing Record  298 of Set 1 | Kutum
# Processing Record  299 of Set 1 | Yumen
# Processing Record  300 of Set 1 | Yarim
# Processing Record  301 of Set 1 | Vao
# Processing Record  302 of Set 1 | Redmond
# Processing Record  303 of Set 1 | Leona Vicario
# Processing Record  304 of Set 1 | Halifax
# Processing Record  305 of Set 1 | Malé
# Processing Record  306 of Set 1 | Siderno
# Processing Record  307 of Set 1 | Hualmay
# Processing Record  308 of Set 1 | Ferkessédougou
# Processing Record  309 of Set 1 | Vincennes
# Processing Record  310 of Set 1 | Lauenburg
# Processing Record  311 of Set 1 | Marzuq
# Processing Record  312 of Set 1 | Hibbing
# Processing Record  313 of Set 1 | Coos Bay
# Processing Record  314 of Set 1 | San Luis
# Processing Record  315 of Set 1 | Mauá
# Processing Record  316 of Set 1 | Akdepe
# Processing Record  317 of Set 1 | Necochea
# Processing Record  318 of Set 1 | Kapit
# Processing Record  319 of Set 1 | Macapá
# Processing Record  320 of Set 1 | Yar-Sale
# Processing Record  321 of Set 1 | Puri
# Processing Record  322 of Set 1 | Fuling
# Processing Record  323 of Set 1 | Corrales
# Processing Record  324 of Set 1 | Phang Nga
# Processing Record  325 of Set 1 | Leningradskiy
# Processing Record  326 of Set 1 | Ørsta
# Processing Record  327 of Set 1 | Santa Fe
# Processing Record  328 of Set 1 | Tessalit
# Processing Record  329 of Set 1 | Amargosa
# Processing Record  330 of Set 1 | Barra do Garças
# Processing Record  331 of Set 1 | Góra Kalwaria
# Processing Record  332 of Set 1 | Hay River
# Processing Record  333 of Set 1 | Hohhot
# Processing Record  334 of Set 1 | Drayton Valley
# Processing Record  335 of Set 1 | Eldorado
# Processing Record  336 of Set 1 | Maturin
# Processing Record  337 of Set 1 | Pisco
# Processing Record  338 of Set 1 | Krasnovishersk
# Processing Record  339 of Set 1 | Longyearbyen
# Processing Record  340 of Set 1 | Lüderitz
# Processing Record  341 of Set 1 | Chapais
# Processing Record  342 of Set 1 | Miragoâne
# Processing Record  343 of Set 1 | Socorro
# Processing Record  344 of Set 1 | Zvornik
# Processing Record  345 of Set 1 | Mackay
# Processing Record  346 of Set 1 | Nizhniy Kuranakh
# Processing Record  347 of Set 1 | Tonstad
# Processing Record  348 of Set 1 | Aygut
# Processing Record  349 of Set 1 | Requena
# Processing Record  350 of Set 1 | Berlevåg
# Processing Record  351 of Set 1 | Fort Nelson
# Processing Record  352 of Set 1 | Hede
# Processing Record  353 of Set 1 | Savonlinna
# Processing Record  354 of Set 1 | Askiz
# Processing Record  355 of Set 1 | Acarí
# Processing Record  356 of Set 1 | Sobolevo
# Processing Record  357 of Set 1 | Linxia Chengguanzhen
# Processing Record  358 of Set 1 | Pochutla
# Processing Record  359 of Set 1 | Warri
# Processing Record  360 of Set 1 | Kitimat
# Processing Record  361 of Set 1 | Saint-François
# Processing Record  362 of Set 1 | Manokwari
# Processing Record  363 of Set 1 | Hambantota
# Processing Record  364 of Set 1 | Harper
# Processing Record  365 of Set 1 | Kamaishi
# Processing Record  366 of Set 1 | Talnakh
# Processing Record  367 of Set 1 | Gary
# Processing Record  368 of Set 1 | Tura
# Processing Record  369 of Set 1 | Kumul
# Processing Record  370 of Set 1 | Nzérékoré
# Processing Record  371 of Set 1 | Sorong
# Processing Record  372 of Set 1 | Lagoa
# Processing Record  373 of Set 1 | Shingū
# Processing Record  374 of Set 1 | Cervo
# Processing Record  375 of Set 1 | Zuwārah
# Processing Record  376 of Set 1 | Port Hedland
# Processing Record  377 of Set 1 | Honiara
# Processing Record  378 of Set 1 | Angul
# Processing Record  379 of Set 1 | Antofagasta
# Processing Record  380 of Set 1 | Mitsamiouli
# Processing Record  381 of Set 1 | Santa Cruz de La Palma
# Processing Record  382 of Set 1 | Laguna
# Processing Record  383 of Set 1 | Qaqortoq
# Processing Record  384 of Set 1 | Vostok
# Processing Record  385 of Set 1 | Marabba
# Processing Record  386 of Set 1 | Erzin
# Processing Record  387 of Set 1 | Calama
# Processing Record  388 of Set 1 | Saint-Augustin
# Processing Record  389 of Set 1 | Rome
# Processing Record  390 of Set 1 | Susa
# Processing Record  391 of Set 1 | Ponta Delgada
# Processing Record  392 of Set 1 | Sena Madureira
# Processing Record  393 of Set 1 | Kharan
# Processing Record  394 of Set 1 | Kemin
# Processing Record  395 of Set 1 | Muncar
# Processing Record  396 of Set 1 | Shimoda
# Processing Record  397 of Set 1 | La Plata
# Processing Record  398 of Set 1 | Woodward
# Processing Record  399 of Set 1 | Miles City
# Processing Record  400 of Set 1 | Aklavik
# Processing Record  401 of Set 1 | Maputo
# Processing Record  402 of Set 1 | Barbacena
# Processing Record  403 of Set 1 | Sibut
# Processing Record  404 of Set 1 | Proletariy
# Processing Record  405 of Set 1 | Jagodina
# Processing Record  406 of Set 1 | Inhambane
# Processing Record  407 of Set 1 | Peleduy
# Processing Record  408 of Set 1 | Riachão
# Processing Record  409 of Set 1 | Kavieng
# Processing Record  410 of Set 1 | Ucluelet
# Processing Record  411 of Set 1 | Potam
# Processing Record  412 of Set 1 | Port Macquarie
# Processing Record  413 of Set 1 | Puerto Nariño
# Processing Record  414 of Set 1 | Tevriz
# Processing Record  415 of Set 1 | Ağdam
# Processing Record  416 of Set 1 | Río Gallegos
# Processing Record  417 of Set 1 | Kultuk
# Processing Record  418 of Set 1 | Guerrero Negro
# Processing Record  419 of Set 1 | Heraclea
# Processing Record  420 of Set 1 | Portland
# Processing Record  421 of Set 1 | Bam
# Processing Record  422 of Set 1 | Marawi
# Processing Record  423 of Set 1 | Hammerfest
# Processing Record  424 of Set 1 | Ust'-Omchug
# Processing Record  425 of Set 1 | Kashary
# Processing Record  426 of Set 1 | Sur
# Processing Record  427 of Set 1 | Morant Bay
# Processing Record  428 of Set 1 | Karratha
# Processing Record  429 of Set 1 | Alice Springs
# Processing Record  430 of Set 1 | Tres Arroyos
# Processing Record  431 of Set 1 | Imbituba
# Processing Record  432 of Set 1 | Ugoofaaru
# Processing Record  433 of Set 1 | San Patricio
# Processing Record  434 of Set 1 | Northam
# Processing Record  435 of Set 1 | Noumea
# Processing Record  436 of Set 1 | Fortuna
# Processing Record  437 of Set 1 | Kambove
# Processing Record  438 of Set 1 | Maceió
# Processing Record  439 of Set 1 | Wasilla
# Processing Record  440 of Set 1 | Abonnema
# Processing Record  441 of Set 1 | Puerto Escondido
# Processing Record  442 of Set 1 | Moyale
# Processing Record  443 of Set 1 | Severobaykal'sk
# Processing Record  444 of Set 1 | Sinop Province
# Processing Record  445 of Set 1 | Seoul
# Processing Record  446 of Set 1 | Martapura
# Processing Record  447 of Set 1 | Villa Carlos Paz
# Processing Record  448 of Set 1 | Wanning
# Processing Record  449 of Set 1 | Amoy
# Processing Record  450 of Set 1 | Tallahassee
# Processing Record  451 of Set 1 | Molochnoye
# Processing Record  452 of Set 1 | Baijiantan
# Processing Record  453 of Set 1 | Topolobampo
# Processing Record  454 of Set 1 | La Plaine
# Processing Record  455 of Set 1 | Luanda
# Processing Record  456 of Set 1 | Asău
# Processing Record  457 of Set 1 | Farīdpur
# Processing Record  458 of Set 1 | Kitui
# Processing Record  459 of Set 1 | Mil'kovo
# Processing Record  460 of Set 1 | Maragogi
# Processing Record  461 of Set 1 | Gaziantep
# Processing Record  462 of Set 1 | Kununurra
# Processing Record  463 of Set 1 | Yinchuan
# Processing Record  464 of Set 1 | Verāval
# Processing Record  465 of Set 1 | Coxim
# Processing Record  466 of Set 1 | Mattru
# Processing Record  467 of Set 1 | Alekseyevsk
# Processing Record  468 of Set 1 | Avanigadda
# Processing Record  469 of Set 1 | Paranaíba
# Processing Record  470 of Set 1 | Bud
# Processing Record  471 of Set 1 | Half Moon Bay
# Processing Record  472 of Set 1 | Aden
# Processing Record  473 of Set 1 | Villa Rica
# Processing Record  474 of Set 1 | Mbandaka
# Processing Record  475 of Set 1 | Nanortalik
# Processing Record  476 of Set 1 | Am Timan
# Processing Record  477 of Set 1 | Coyoles
# Processing Record  478 of Set 1 | Hermiston
# Processing Record  479 of Set 1 | Sinnamary
# Processing Record  480 of Set 1 | Labuhan
# Processing Record  481 of Set 1 | Gamba
# Processing Record  482 of Set 1 | Vila
# Processing Record  483 of Set 1 | Chicama
# Processing Record  484 of Set 1 | Garachiné
# Processing Record  485 of Set 1 | Port Augusta
# Processing Record  486 of Set 1 | Mossamedes
# Processing Record  487 of Set 1 | Ixtapa
# Processing Record  488 of Set 1 | Rivera
# Processing Record  489 of Set 1 | Itaueira
# Processing Record  490 of Set 1 | Burley
# Processing Record  491 of Set 1 | Soure
# Processing Record  492 of Set 1 | Kugesi
# Processing Record  493 of Set 1 | Antequera
# Processing Record  494 of Set 1 | Thinadhoo
# Processing Record  495 of Set 1 | Doka
# Processing Record  496 of Set 1 | Marabá
# Processing Record  497 of Set 1 | Gien
# Processing Record  498 of Set 1 | Pevek
# Processing Record  499 of Set 1 | Yenangyaung
# Processing Record  500 of Set 1 | Te Anau
# Processing Record  501 of Set 1 | Glenwood Springs
# Processing Record  502 of Set 1 | Yomou
# Processing Record  503 of Set 1 | Esil
# Processing Record  504 of Set 1 | Fereydūnkenār
# Processing Record  505 of Set 1 | Winslow
# Processing Record  506 of Set 1 | Gouré
# Processing Record  507 of Set 1 | Pucallpa
# Processing Record  508 of Set 1 | Sheopur
# Processing Record  509 of Set 1 | Trairi
# Processing Record  510 of Set 1 | Montanha
# Processing Record  511 of Set 1 | Kavaratti
# Processing Record  512 of Set 1 | San Policarpo
# Processing Record  513 of Set 1 | San Miguel
# Processing Record  514 of Set 1 | La Santisima Trinidad
# Processing Record  515 of Set 1 | Bose
# Processing Record  516 of Set 1 | Lavrentiya
# Processing Record  517 of Set 1 | Udachny
# Processing Record  518 of Set 1 | Zemio
# Processing Record  519 of Set 1 | Punta Cardon
# Processing Record  520 of Set 1 | Vila Velha
# Processing Record  521 of Set 1 | Kpandae
# Processing Record  522 of Set 1 | Kruisfontein
# Processing Record  523 of Set 1 | Piaçabuçu
# Processing Record  524 of Set 1 | Havøysund
# Processing Record  525 of Set 1 | Santos Dumont
# Processing Record  526 of Set 1 | Turbat
# Processing Record  527 of Set 1 | Seymchan
# Processing Record  528 of Set 1 | Edd
# Processing Record  529 of Set 1 | Tutóia
# Processing Record  530 of Set 1 | Ocós
# Processing Record  531 of Set 1 | Reconquista
# Processing Record  532 of Set 1 | Ostrovnoy
# Processing Record  533 of Set 1 | Umm Kaddadah
# Processing Record  534 of Set 1 | Loučovice
# Processing Record  535 of Set 1 | Oodweyne
# Processing Record  536 of Set 1 | Bang Saphan
# Processing Record  537 of Set 1 | Basco
# Processing Record  538 of Set 1 | Porto Santo
# Processing Record  539 of Set 1 | Aitape
# Processing Record  540 of Set 1 | Sumbe
# Processing Record  541 of Set 1 | Ratnagiri
# Processing Record  542 of Set 1 | Pauna
# Processing Record  543 of Set 1 | Durant
# Processing Record  544 of Set 1 | Campbellsville
# Processing Record  545 of Set 1 | Biri
# Processing Record  546 of Set 1 | Sæby
# Processing Record  547 of Set 1 | Ambon City
# Processing Record  548 of Set 1 | Dingle
# Processing Record  549 of Set 1 | Konëvo
# Processing Record  550 of Set 1 | Svalyava
# Processing Record  551 of Set 1 | Fenoarivo
# Processing Record  552 of Set 1 | Egvekinot
# Processing Record  553 of Set 1 | Dunedin
# Processing Record  554 of Set 1 | Perth
# Processing Record  555 of Set 1 | Tazovsky
# Processing Record  556 of Set 1 | Chimbote
# Processing Record  557 of Set 1 | Albury
# Processing Record  558 of Set 1 | Bhawānipatna
# Processing Record  559 of Set 1 | Kargasok
# Processing Record  560 of Set 1 | Kokstad

# %%
# Creating the dataframe by putting it first into a dictionary, and then into the dataframe
weather_dict = {
    'City': new_city,
    'Latitude': lat,
    'Longitude': long,
    'Max Temp': maxtemp,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind Speed': wind_speed,
    'Country': country
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Taking the dataframe and storing as a .csv file for use in Vacation.Py
weather_data.to_csv(r'output.csv', index = False)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Displaying the new dataframe!
weather_data
# **** Note: I took the **Max Temp** specifically because that is what was displayed in the starter code walkthrough!
# Out:
#                       City  Latitude  Longitude  Max Temp  Humidity  \
# 0                Saskylakh   71.9167   114.0833    -26.18        96
# 1                   Atuona   -9.8000  -139.0333     79.75        70
# 2                   Torbay   47.6666   -52.7314     28.99        80
# 3              Yellowknife   62.4560  -114.3525      0.00        60
# 4    Los Llanos de Aridane   28.6585   -17.9182     66.20        68
# ..                     ...       ...        ...       ...       ...
# 555               Chimbote   -9.0853   -78.5783     79.05        65
# 556                 Albury  -36.0833   146.9167     57.00        94
# 557           Bhawānipatna   19.9000    83.1667     73.99        36
# 558               Kargasok   59.0556    80.8572     16.57        94
# 559                Kokstad  -30.5472    29.4241     65.48        79
#
#      Cloudiness  Wind Speed Country
# 0            84        4.72      RU
# 1            91       12.12      PF
# 2            90        3.44      CA
# 3             1        4.61      CA
# 4            75       13.80      ES
# ..          ...         ...     ...
# 555          71       11.92      PE
# 556           0        3.80      AU
# 557           0        5.01      IN
# 558         100        8.66      RU
# 559          93        2.13      ZA
#
# [560 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Finding out if there are any values in the column "Humidity" that are over 100%
new = weather_data.loc[weather_data['Humidity'] > 100]
new
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
# Splitting into Northern Hemisphere...

northern_hemi = weather_data.loc[weather_data['Latitude'] >= 0]
northern_hemi
# Out:
#                       City  Latitude  Longitude  Max Temp  Humidity  \
# 0                Saskylakh   71.9167   114.0833    -26.18        96
# 2                   Torbay   47.6666   -52.7314     28.99        80
# 3              Yellowknife   62.4560  -114.3525      0.00        60
# 4    Los Llanos de Aridane   28.6585   -17.9182     66.20        68
# 5               Port Hardy   50.6996  -127.4199     39.20        70
# ..                     ...       ...        ...       ...       ...
# 549               Svalyava   48.5485    22.9958     42.01        80
# 551              Egvekinot   66.3167  -179.1667     -2.94        94
# 554               Tazovsky   67.4667    78.7000    -13.05        86
# 557           Bhawānipatna   19.9000    83.1667     73.99        36
# 558               Kargasok   59.0556    80.8572     16.57        94
#
#      Cloudiness  Wind Speed Country
# 0            84        4.72      RU
# 2            90        3.44      CA
# 3             1        4.61      CA
# 4            75       13.80      ES
# 5            20        9.22      CA
# ..          ...         ...     ...
# 549         100        7.90      UA
# 551          98        6.80      RU
# 554          83        8.75      RU
# 557           0        5.01      IN
# 558         100        8.66      RU
#
# [376 rows x 8 columns]

# %%
#And southern hemisphere here ->
southern_hemi = weather_data.loc[weather_data['Latitude'] < 0]
southern_hemi
# Out:
#           City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 1       Atuona   -9.8000  -139.0333     79.75        70          91
# 6     Aripuanã   -9.1667   -60.6333     82.45        85         100
# 8    Carnarvon  -24.8667   113.6333     80.60        78          40
# 10      Castro  -24.7911   -50.0119     76.01        74          14
# 12        Chui  -33.6971   -53.4616     74.57        68         100
# ..         ...       ...        ...       ...       ...         ...
# 552    Dunedin  -45.8742   170.5036     52.00        76          22
# 553      Perth  -31.9333   115.8333     73.00        33           0
# 555   Chimbote   -9.0853   -78.5783     79.05        65          71
# 556     Albury  -36.0833   146.9167     57.00        94           0
# 559    Kokstad  -30.5472    29.4241     65.48        79          93
#
#      Wind Speed Country
# 1         12.12      PF
# 6          1.92      BR
# 8          8.05      AU
# 10         5.28      BR
# 12        10.87      UY
# ..          ...     ...
# 552        3.00      NZ
# 553       13.80      AU
# 555       11.92      PE
# 556        3.80      AU
# 559        2.13      ZA
#
# [184 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

sns.scatterplot(weather_data['Latitude'], weather_data['Max Temp'], marker="o", palette=cmap, hue=weather_data['Latitude'])
plt.title('Latitude vs Temperature Plot')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('latitude_vs_temp')
# Out:
# /Users/jameswhite/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# With this temperature plot, it looks as though as the latitude increases, the temperature drops off.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
sns.scatterplot(weather_data['Latitude'], weather_data['Humidity'], marker="o", palette=cmap, hue=weather_data['Latitude'])
plt.title('Latitude vs Humidity Plot')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('latitude_vs_humidity')
# Out:
# /Users/jameswhite/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# There isn't much to tell from this data other then there seem to be some clustering in the top left and top right,
# that may indicate there tends to be more humidty the more north and south you go.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
sns.scatterplot(weather_data['Latitude'], weather_data['Cloudiness'], marker="o", palette=cmap,  hue=weather_data['Latitude'])
plt.title('Latitude vs Cloudiness Plot')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('latitude_vs_cloudiness')

# %%
# Again, this one is a bit harder to form conclusions about ,but it looks as though
# a good amount of either full cloudiness or none at all occur at all points along the latitude axis

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Wind Speed'], marker="o", facecolors="red", edgecolors="black")
plt.title('Latitude vs Wind Speed Plot')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('latitude_vs_windspeed')

# %%
# With this particular plot, most of the data lies below the 15 mph mark for all the latitudes observed.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Max Temp'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')
plt.title('Max Temp vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_temp_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.8165065219667993

# %%
# It looks as though there is a clear trend downward for latitude downward as the max temp increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Max Temp'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')
plt.title('Max Temp vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_temp_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.3357300769211709

# %%
# Though not as concise a scatter plot as the last one, it looks as though there is a trend upward for latitude downward as the max temp increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Humidity'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')
plt.title('Humidity vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_humidity_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.08569406872376387

# %%
# There appears to be a slight increase in humidity as the latitudes increase

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Humidity'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')
plt.title('Humidity vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_humidity_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.015242857543299512

# %%
# Inversely, it looks as though as the latitudes decrease, the humidity increases

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Cloudiness'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')
plt.title('Cloudiness vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_cloudiness_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.043476010702200765

# %%
# These next two plots are a bit harder to truly come to a conclusion. It looks as though most of the data
# is clustered on either end of the cloudiness scale (close to 0 and around 100), as shown by the previous
# scatter plot shown above (Latitude vs Cloudiness)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Cloudiness'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')
plt.title('Cloudiness vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_humidity_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.006349704063505126

# %%
# The same thing, but a bit less so, as there aren't as many data points, but it also looks as though
# most of the data points are on either end of the cloudiness range

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Wind Speed'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Wind Speed vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_windspeed_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.01593679450870741

# %%
# It appears as though most of the data points lie around where the wind speed is < 15 or so. Thus, latitude
# isn't as much a factor here as it is with other plots

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Wind Speed'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Wind Speed vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_windspeed_latitude')
# Show plot
plt.show()
# Out:
# R squared: 0.07665588180146471

# %%
# This one is a bit more obscure though the linear regression shows a similar relationship; as the latitudes
# get closer to the south pole, the wind speed tends to drop off a bit.
