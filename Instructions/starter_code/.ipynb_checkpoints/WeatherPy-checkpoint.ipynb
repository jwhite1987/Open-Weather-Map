# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 637

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
units = 'imperial'
url = "http://api.openweathermap.org/data/2.5/weather?"    

lat = []
long = []
maxtemp = []
humidity = []
clouds = []
wind_speed = []
country = []
new_city = []
counter = 1

# %%
for city in cities:
    query_url = f'{url}appid={weather_api_key}&units={units}&q={city}'
    data = requests.get(query_url)
    data2 = data.json()
    if counter == 1:
        print('Beginning Data Retrieval:\n---------------------------')
    try: 
        new_city.append(data2['name'])
        lat.append(data2['coord']['lat'])
        long.append(data2['coord']['lon'])
        maxtemp.append(data2['main']['temp_max'])
        humidity.append(data2['main']['humidity'])
        clouds.append(data2['clouds']['all'])
        wind_speed.append(data2['wind']['speed'])
        country.append(data2['sys']['country'])
        current_city = data2['name']
        print(f'Processing Record  {counter} of Set 1 | {current_city}')
        counter += 1
    except:
        pass
# Out:
# Beginning Data Retrieval:
# ---------------------------
# Processing Record  1 of Set 1 | Iqaluit
# Processing Record  2 of Set 1 | Salalah
# Processing Record  3 of Set 1 | Qaanaaq
# Processing Record  4 of Set 1 | Guerrero Negro
# Processing Record  5 of Set 1 | Ushuaia
# Processing Record  6 of Set 1 | Santa Fe
# Processing Record  7 of Set 1 | Atuona
# Processing Record  8 of Set 1 | Isangel
# Processing Record  9 of Set 1 | Rikitea
# Processing Record  10 of Set 1 | Khatanga
# Processing Record  11 of Set 1 | Albany
# Processing Record  12 of Set 1 | Hithadhoo
# Processing Record  13 of Set 1 | Kaitangata
# Processing Record  14 of Set 1 | Ribeira Grande
# Processing Record  15 of Set 1 | Punta Arenas
# Processing Record  16 of Set 1 | Jamestown
# Processing Record  17 of Set 1 | Hermanus
# Processing Record  18 of Set 1 | Wattegama
# Processing Record  19 of Set 1 | Leningradskiy
# Processing Record  20 of Set 1 | Mataura
# Processing Record  21 of Set 1 | Tual
# Processing Record  22 of Set 1 | Kembé
# Processing Record  23 of Set 1 | Namwala
# Processing Record  24 of Set 1 | Bluff
# Processing Record  25 of Set 1 | Abhā
# Processing Record  26 of Set 1 | Saint Paul Harbor
# Processing Record  27 of Set 1 | Sonāmukhi
# Processing Record  28 of Set 1 | Kruisfontein
# Processing Record  29 of Set 1 | Paragominas
# Processing Record  30 of Set 1 | Paralímni
# Processing Record  31 of Set 1 | Coquimbo
# Processing Record  32 of Set 1 | Lixouri
# Processing Record  33 of Set 1 | Tuktoyaktuk
# Processing Record  34 of Set 1 | Busselton
# Processing Record  35 of Set 1 | Pathein
# Processing Record  36 of Set 1 | Shenjiamen
# Processing Record  37 of Set 1 | Jinxiang
# Processing Record  38 of Set 1 | Guymon
# Processing Record  39 of Set 1 | Lompoc
# Processing Record  40 of Set 1 | Guánica
# Processing Record  41 of Set 1 | Arraial do Cabo
# Processing Record  42 of Set 1 | Tessalit
# Processing Record  43 of Set 1 | Severo-Yeniseyskiy
# Processing Record  44 of Set 1 | Kharagpur
# Processing Record  45 of Set 1 | Shingū
# Processing Record  46 of Set 1 | Bethel
# Processing Record  47 of Set 1 | George Town
# Processing Record  48 of Set 1 | Saldanha
# Processing Record  49 of Set 1 | Bengkulu
# Processing Record  50 of Set 1 | Chokurdakh
# Processing Record  51 of Set 1 | Samarai
# Processing Record  52 of Set 1 | Barrow
# Processing Record  53 of Set 1 | Businga
# Processing Record  54 of Set 1 | Thompson
# Processing Record  55 of Set 1 | Nouakchott
# Processing Record  56 of Set 1 | Cape Town
# Processing Record  57 of Set 1 | Chui
# Processing Record  58 of Set 1 | Yellowknife
# Processing Record  59 of Set 1 | Srandakan
# Processing Record  60 of Set 1 | Harper
# Processing Record  61 of Set 1 | Ilulissat
# Processing Record  62 of Set 1 | Akdağmadeni
# Processing Record  63 of Set 1 | Puerto Ayora
# Processing Record  64 of Set 1 | Chitral
# Processing Record  65 of Set 1 | Port Alfred
# Processing Record  66 of Set 1 | Boyolangu
# Processing Record  67 of Set 1 | Hambantota
# Processing Record  68 of Set 1 | Ormara
# Processing Record  69 of Set 1 | General Roca
# Processing Record  70 of Set 1 | Los Llanos de Aridane
# Processing Record  71 of Set 1 | Khanbari
# Processing Record  72 of Set 1 | Gizo Government Station
# Processing Record  73 of Set 1 | Nikolskoye
# Processing Record  74 of Set 1 | Avarua
# Processing Record  75 of Set 1 | Dikson
# Processing Record  76 of Set 1 | Kostanay
# Processing Record  77 of Set 1 | Yulara
# Processing Record  78 of Set 1 | Atar
# Processing Record  79 of Set 1 | Mossamedes
# Processing Record  80 of Set 1 | Vaini
# Processing Record  81 of Set 1 | Klaksvík
# Processing Record  82 of Set 1 | São Filipe
# Processing Record  83 of Set 1 | Hasaki
# Processing Record  84 of Set 1 | Severo-Kuril'sk
# Processing Record  85 of Set 1 | Pevek
# Processing Record  86 of Set 1 | Longyearbyen
# Processing Record  87 of Set 1 | Zhangjiakou
# Processing Record  88 of Set 1 | Hobart
# Processing Record  89 of Set 1 | Sorong
# Processing Record  90 of Set 1 | Ahipara
# Processing Record  91 of Set 1 | Dunedin
# Processing Record  92 of Set 1 | Shimoda
# Processing Record  93 of Set 1 | Provideniya
# Processing Record  94 of Set 1 | Saint-Philippe
# Processing Record  95 of Set 1 | Mwinilunga
# Processing Record  96 of Set 1 | San Patricio
# Processing Record  97 of Set 1 | Tabuk
# Processing Record  98 of Set 1 | Beyneu
# Processing Record  99 of Set 1 | Tuatapere
# Processing Record  100 of Set 1 | Hofn
# Processing Record  101 of Set 1 | Torbay
# Processing Record  102 of Set 1 | Caravelas
# Processing Record  103 of Set 1 | Sinop Province
# Processing Record  104 of Set 1 | Codrington
# Processing Record  105 of Set 1 | Korla
# Processing Record  106 of Set 1 | Mayumba
# Processing Record  107 of Set 1 | Naryan-Mar
# Processing Record  108 of Set 1 | Waddān
# Processing Record  109 of Set 1 | Beringovskiy
# Processing Record  110 of Set 1 | Aswān
# Processing Record  111 of Set 1 | Luga
# Processing Record  112 of Set 1 | Vila Franca do Campo
# Processing Record  113 of Set 1 | Noumea
# Processing Record  114 of Set 1 | Borogontsy
# Processing Record  115 of Set 1 | Kapaa
# Processing Record  116 of Set 1 | Port Elizabeth
# Processing Record  117 of Set 1 | Chapada dos Guimarães
# Processing Record  118 of Set 1 | Campoverde
# Processing Record  119 of Set 1 | Saint George
# Processing Record  120 of Set 1 | Fort-Shevchenko
# Processing Record  121 of Set 1 | Peniche
# Processing Record  122 of Set 1 | Bredasdorp
# Processing Record  123 of Set 1 | Chifeng
# Processing Record  124 of Set 1 | Bathsheba
# Processing Record  125 of Set 1 | Canto do Buriti
# Processing Record  126 of Set 1 | Carnarvon
# Processing Record  127 of Set 1 | Ixtapa
# Processing Record  128 of Set 1 | Liverpool
# Processing Record  129 of Set 1 | Norman Wells
# Processing Record  130 of Set 1 | Marawi
# Processing Record  131 of Set 1 | Bambous Virieux
# Processing Record  132 of Set 1 | Hirara
# Processing Record  133 of Set 1 | Mahébourg
# Processing Record  134 of Set 1 | Whitianga
# Processing Record  135 of Set 1 | Golden
# Processing Record  136 of Set 1 | Jumla
# Processing Record  137 of Set 1 | Esim
# Processing Record  138 of Set 1 | Nizhneangarsk
# Processing Record  139 of Set 1 | New Norfolk
# Processing Record  140 of Set 1 | Saint-Joseph
# Processing Record  141 of Set 1 | Burnie
# Processing Record  142 of Set 1 | Castro
# Processing Record  143 of Set 1 | Olafsvik
# Processing Record  144 of Set 1 | Nacala
# Processing Record  145 of Set 1 | Bang Saphan
# Processing Record  146 of Set 1 | Aklavik
# Processing Record  147 of Set 1 | Pushchino
# Processing Record  148 of Set 1 | Bandarbeyla
# Processing Record  149 of Set 1 | Batagay-Alyta
# Processing Record  150 of Set 1 | San Quintín
# Processing Record  151 of Set 1 | Zhangye
# Processing Record  152 of Set 1 | East London
# Processing Record  153 of Set 1 | Cabo San Lucas
# Processing Record  154 of Set 1 | Clyde River
# Processing Record  155 of Set 1 | Marand
# Processing Record  156 of Set 1 | Sulangan
# Processing Record  157 of Set 1 | Upernavik
# Processing Record  158 of Set 1 | Esperance
# Processing Record  159 of Set 1 | Porto-Novo
# Processing Record  160 of Set 1 | Kapoeta
# Processing Record  161 of Set 1 | Al Bardīyah
# Processing Record  162 of Set 1 | Baykit
# Processing Record  163 of Set 1 | Richards Bay
# Processing Record  164 of Set 1 | Amahai
# Processing Record  165 of Set 1 | Taraz
# Processing Record  166 of Set 1 | Sur
# Processing Record  167 of Set 1 | Tonantins
# Processing Record  168 of Set 1 | Faanui
# Processing Record  169 of Set 1 | Rafai
# Processing Record  170 of Set 1 | Gao
# Processing Record  171 of Set 1 | Priego de Córdoba
# Processing Record  172 of Set 1 | Qinhuangdao
# Processing Record  173 of Set 1 | Wanning
# Processing Record  174 of Set 1 | Şabyā
# Processing Record  175 of Set 1 | Goma
# Processing Record  176 of Set 1 | Lüderitz
# Processing Record  177 of Set 1 | Kismayo
# Processing Record  178 of Set 1 | Lagoa
# Processing Record  179 of Set 1 | São Félix do Xingu
# Processing Record  180 of Set 1 | Września
# Processing Record  181 of Set 1 | Upata
# Processing Record  182 of Set 1 | Hammerfest
# Processing Record  183 of Set 1 | Wilmington
# Processing Record  184 of Set 1 | Medveda
# Processing Record  185 of Set 1 | Panabá
# Processing Record  186 of Set 1 | Anloga
# Processing Record  187 of Set 1 | Meulaboh
# Processing Record  188 of Set 1 | Ojinaga
# Processing Record  189 of Set 1 | Nome
# Processing Record  190 of Set 1 | Ariquemes
# Processing Record  191 of Set 1 | Acajutla
# Processing Record  192 of Set 1 | Hamilton
# Processing Record  193 of Set 1 | Hilo
# Processing Record  194 of Set 1 | Berlevåg
# Processing Record  195 of Set 1 | Kavieng
# Processing Record  196 of Set 1 | Okha
# Processing Record  197 of Set 1 | Canosa di Puglia
# Processing Record  198 of Set 1 | Kahului
# Processing Record  199 of Set 1 | Betsiamites
# Processing Record  200 of Set 1 | Jinka
# Processing Record  201 of Set 1 | Abrau-Dyurso
# Processing Record  202 of Set 1 | Cidreira
# Processing Record  203 of Set 1 | Santa Maria
# Processing Record  204 of Set 1 | Vadsø
# Processing Record  205 of Set 1 | Saint Anthony
# Processing Record  206 of Set 1 | Nālūt
# Processing Record  207 of Set 1 | Angoche
# Processing Record  208 of Set 1 | Nizwá
# Processing Record  209 of Set 1 | Pāsighāt
# Processing Record  210 of Set 1 | Qasigiannguit
# Processing Record  211 of Set 1 | Waipawa
# Processing Record  212 of Set 1 | Kutum
# Processing Record  213 of Set 1 | Quatre Cocos
# Processing Record  214 of Set 1 | Linjiang
# Processing Record  215 of Set 1 | Saskylakh
# Processing Record  216 of Set 1 | Nanortalik
# Processing Record  217 of Set 1 | Butaritari
# Processing Record  218 of Set 1 | Husavik
# Processing Record  219 of Set 1 | Deputatsky
# Processing Record  220 of Set 1 | Kiryat Gat
# Processing Record  221 of Set 1 | Honiara
# Processing Record  222 of Set 1 | Te Anau
# Processing Record  223 of Set 1 | Marquette
# Processing Record  224 of Set 1 | San Vicente
# Processing Record  225 of Set 1 | Pangnirtung
# Processing Record  226 of Set 1 | Jiwani
# Processing Record  227 of Set 1 | Cap Malheureux
# Processing Record  228 of Set 1 | Matveyevka
# Processing Record  229 of Set 1 | Daru
# Processing Record  230 of Set 1 | Havøysund
# Processing Record  231 of Set 1 | Casablanca
# Processing Record  232 of Set 1 | Dosso
# Processing Record  233 of Set 1 | Taoudenni
# Processing Record  234 of Set 1 | Cherskiy
# Processing Record  235 of Set 1 | Asău
# Processing Record  236 of Set 1 | Hingoli
# Processing Record  237 of Set 1 | Praia da Vitória
# Processing Record  238 of Set 1 | Mehamn
# Processing Record  239 of Set 1 | Narsaq
# Processing Record  240 of Set 1 | Chicama
# Processing Record  241 of Set 1 | Nemuro
# Processing Record  242 of Set 1 | Mar del Plata
# Processing Record  243 of Set 1 | Khartoum
# Processing Record  244 of Set 1 | Pailón
# Processing Record  245 of Set 1 | Aksay
# Processing Record  246 of Set 1 | Lebu
# Processing Record  247 of Set 1 | Oga
# Processing Record  248 of Set 1 | Denpasar
# Processing Record  249 of Set 1 | Morgan City
# Processing Record  250 of Set 1 | Sabang
# Processing Record  251 of Set 1 | Porto Velho
# Processing Record  252 of Set 1 | Mpwapwa
# Processing Record  253 of Set 1 | Tiksi
# Processing Record  254 of Set 1 | Vila
# Processing Record  255 of Set 1 | Kizner
# Processing Record  256 of Set 1 | Palmares do Sul
# Processing Record  257 of Set 1 | Dondo
# Processing Record  258 of Set 1 | Flin Flon
# Processing Record  259 of Set 1 | North Bend
# Processing Record  260 of Set 1 | Grand Forks
# Processing Record  261 of Set 1 | Matagami
# Processing Record  262 of Set 1 | Palāsa
# Processing Record  263 of Set 1 | Valdivia
# Processing Record  264 of Set 1 | Manggar
# Processing Record  265 of Set 1 | Santa Vitória do Palmar
# Processing Record  266 of Set 1 | Sakaiminato
# Processing Record  267 of Set 1 | Mareeba
# Processing Record  268 of Set 1 | Chubbuck
# Processing Record  269 of Set 1 | Tasiilaq
# Processing Record  270 of Set 1 | Roald
# Processing Record  271 of Set 1 | Kieta
# Processing Record  272 of Set 1 | Obo
# Processing Record  273 of Set 1 | Fes
# Processing Record  274 of Set 1 | Ipixuna
# Processing Record  275 of Set 1 | Constitución
# Processing Record  276 of Set 1 | Aasiaat
# Processing Record  277 of Set 1 | Merauke
# Processing Record  278 of Set 1 | Belle Glade
# Processing Record  279 of Set 1 | Sawtell
# Processing Record  280 of Set 1 | Khovd
# Processing Record  281 of Set 1 | Tubmanburg
# Processing Record  282 of Set 1 | Beira
# Processing Record  283 of Set 1 | Tazovsky
# Processing Record  284 of Set 1 | Grosse Pointe Park
# Processing Record  285 of Set 1 | Zima
# Processing Record  286 of Set 1 | Santa
# Processing Record  287 of Set 1 | Salinópolis
# Processing Record  288 of Set 1 | Tamale
# Processing Record  289 of Set 1 | Luanda
# Processing Record  290 of Set 1 | Tomatlán
# Processing Record  291 of Set 1 | Togur
# Processing Record  292 of Set 1 | Stepnogorsk
# Processing Record  293 of Set 1 | Tura
# Processing Record  294 of Set 1 | Mimoso do Sul
# Processing Record  295 of Set 1 | Lālmohan
# Processing Record  296 of Set 1 | Kultuk
# Processing Record  297 of Set 1 | Lata
# Processing Record  298 of Set 1 | Airai
# Processing Record  299 of Set 1 | Bulz
# Processing Record  300 of Set 1 | Chara
# Processing Record  301 of Set 1 | Niquero
# Processing Record  302 of Set 1 | Colomiers
# Processing Record  303 of Set 1 | San Lorenzo
# Processing Record  304 of Set 1 | Volchikha
# Processing Record  305 of Set 1 | Terrace
# Processing Record  306 of Set 1 | Nyurba
# Processing Record  307 of Set 1 | Gamba
# Processing Record  308 of Set 1 | Tutóia
# Processing Record  309 of Set 1 | Kyzyl-Suu
# Processing Record  310 of Set 1 | Buala
# Processing Record  311 of Set 1 | Newport
# Processing Record  312 of Set 1 | Winburg
# Processing Record  313 of Set 1 | Eureka
# Processing Record  314 of Set 1 | Aninoasa
# Processing Record  315 of Set 1 | Borger
# Processing Record  316 of Set 1 | Jalu
# Processing Record  317 of Set 1 | Port-Gentil
# Processing Record  318 of Set 1 | Oodweyne
# Processing Record  319 of Set 1 | Faya
# Processing Record  320 of Set 1 | Waingapu
# Processing Record  321 of Set 1 | Nioro
# Processing Record  322 of Set 1 | Evensk
# Processing Record  323 of Set 1 | Neryungri
# Processing Record  324 of Set 1 | Batemans Bay
# Processing Record  325 of Set 1 | Kumul
# Processing Record  326 of Set 1 | Tommot
# Processing Record  327 of Set 1 | Pesaro
# Processing Record  328 of Set 1 | Banda Aceh
# Processing Record  329 of Set 1 | Kushmurun
# Processing Record  330 of Set 1 | Chimbote
# Processing Record  331 of Set 1 | Saint-François
# Processing Record  332 of Set 1 | Sunrise Manor
# Processing Record  333 of Set 1 | Zapolyarnyy
# Processing Record  334 of Set 1 | Camacupa
# Processing Record  335 of Set 1 | Bārmer
# Processing Record  336 of Set 1 | Bubaque
# Processing Record  337 of Set 1 | Alta Floresta
# Processing Record  338 of Set 1 | Keti Bandar
# Processing Record  339 of Set 1 | Vostok
# Processing Record  340 of Set 1 | Kagoro
# Processing Record  341 of Set 1 | Alpena
# Processing Record  342 of Set 1 | Verkhoyansk
# Processing Record  343 of Set 1 | Ulaangom
# Processing Record  344 of Set 1 | Dingle
# Processing Record  345 of Set 1 | Ihosy
# Processing Record  346 of Set 1 | Pochutla
# Processing Record  347 of Set 1 | Gravdal
# Processing Record  348 of Set 1 | Kysyl-Syr
# Processing Record  349 of Set 1 | Hay River
# Processing Record  350 of Set 1 | Carutapera
# Processing Record  351 of Set 1 | Muros
# Processing Record  352 of Set 1 | Awjilah
# Processing Record  353 of Set 1 | Ancud
# Processing Record  354 of Set 1 | Karaton
# Processing Record  355 of Set 1 | Labuhan
# Processing Record  356 of Set 1 | Geraldton
# Processing Record  357 of Set 1 | Arrondissement de Millau
# Processing Record  358 of Set 1 | Katsuura
# Processing Record  359 of Set 1 | Namtsy
# Processing Record  360 of Set 1 | Flinders
# Processing Record  361 of Set 1 | Søgne
# Processing Record  362 of Set 1 | Xingyi
# Processing Record  363 of Set 1 | San Cristobal
# Processing Record  364 of Set 1 | Kostomuksha
# Processing Record  365 of Set 1 | Peace River
# Processing Record  366 of Set 1 | Horadiz
# Processing Record  367 of Set 1 | Greenville
# Processing Record  368 of Set 1 | Arrondissement de Lannion
# Processing Record  369 of Set 1 | Foumban
# Processing Record  370 of Set 1 | Sitka
# Processing Record  371 of Set 1 | Māngrol
# Processing Record  372 of Set 1 | Lodwar
# Processing Record  373 of Set 1 | Rafrāf
# Processing Record  374 of Set 1 | Smoky Lake
# Processing Record  375 of Set 1 | Vardø
# Processing Record  376 of Set 1 | San Jose de Guanipa
# Processing Record  377 of Set 1 | Prieska
# Processing Record  378 of Set 1 | Crotone
# Processing Record  379 of Set 1 | Bom Jesus
# Processing Record  380 of Set 1 | Isla Mujeres
# Processing Record  381 of Set 1 | Santo Augusto
# Processing Record  382 of Set 1 | Port Hedland
# Processing Record  383 of Set 1 | Rundu
# Processing Record  384 of Set 1 | Ponta do Sol
# Processing Record  385 of Set 1 | Córdoba
# Processing Record  386 of Set 1 | Medicine Hat
# Processing Record  387 of Set 1 | Ferrol
# Processing Record  388 of Set 1 | Maraã
# Processing Record  389 of Set 1 | Sucúa
# Processing Record  390 of Set 1 | Chapleau
# Processing Record  391 of Set 1 | Alofi
# Processing Record  392 of Set 1 | Qaqortoq
# Processing Record  393 of Set 1 | West Bay
# Processing Record  394 of Set 1 | Cleburne
# Processing Record  395 of Set 1 | Fort Nelson
# Processing Record  396 of Set 1 | Dali
# Processing Record  397 of Set 1 | Paramonga
# Processing Record  398 of Set 1 | Chibombo
# Processing Record  399 of Set 1 | Ghanzi
# Processing Record  400 of Set 1 | Zuwārah
# Processing Record  401 of Set 1 | Ambilobe
# Processing Record  402 of Set 1 | Tilichiki
# Processing Record  403 of Set 1 | Kisangani
# Processing Record  404 of Set 1 | San Mateo del Mar
# Processing Record  405 of Set 1 | Fortuna
# Processing Record  406 of Set 1 | Kuril'sk
# Processing Record  407 of Set 1 | Ngunguru
# Processing Record  408 of Set 1 | Berdigestyakh
# Processing Record  409 of Set 1 | Fairbanks
# Processing Record  410 of Set 1 | Torrington
# Processing Record  411 of Set 1 | Padang
# Processing Record  412 of Set 1 | Langham
# Processing Record  413 of Set 1 | Goderich
# Processing Record  414 of Set 1 | Rocha
# Processing Record  415 of Set 1 | Taksimo
# Processing Record  416 of Set 1 | Lake City
# Processing Record  417 of Set 1 | Katobu
# Processing Record  418 of Set 1 | Nanchang
# Processing Record  419 of Set 1 | Kupang
# Processing Record  420 of Set 1 | Palafrugell
# Processing Record  421 of Set 1 | Kropotkin
# Processing Record  422 of Set 1 | Souillac
# Processing Record  423 of Set 1 | Mount Isa
# Processing Record  424 of Set 1 | Athabasca
# Processing Record  425 of Set 1 | Kirakira
# Processing Record  426 of Set 1 | Ewo
# Processing Record  427 of Set 1 | Sarangani
# Processing Record  428 of Set 1 | Leh
# Processing Record  429 of Set 1 | Erzin
# Processing Record  430 of Set 1 | Ballina
# Processing Record  431 of Set 1 | Yar-Sale
# Processing Record  432 of Set 1 | Ostrovnoy
# Processing Record  433 of Set 1 | Brasiléia
# Processing Record  434 of Set 1 | Portland
# Processing Record  435 of Set 1 | Trofaiach
# Processing Record  436 of Set 1 | Hokitika
# Processing Record  437 of Set 1 | Port Macquarie
# Processing Record  438 of Set 1 | Half Moon Bay
# Processing Record  439 of Set 1 | Nelson Bay
# Processing Record  440 of Set 1 | Port Lincoln
# Processing Record  441 of Set 1 | Elliot
# Processing Record  442 of Set 1 | Bowen
# Processing Record  443 of Set 1 | Raudeberg
# Processing Record  444 of Set 1 | Ahome
# Processing Record  445 of Set 1 | Rivera
# Processing Record  446 of Set 1 | Enterprise
# Processing Record  447 of Set 1 | Yumen
# Processing Record  448 of Set 1 | Pisco
# Processing Record  449 of Set 1 | Prince Rupert
# Processing Record  450 of Set 1 | Nhulunbuy
# Processing Record  451 of Set 1 | Tiarei
# Processing Record  452 of Set 1 | Banikoara
# Processing Record  453 of Set 1 | Philadelphia
# Processing Record  454 of Set 1 | Hong Kong
# Processing Record  455 of Set 1 | Xining
# Processing Record  456 of Set 1 | Jerantut
# Processing Record  457 of Set 1 | The Valley
# Processing Record  458 of Set 1 | São Mateus do Sul
# Processing Record  459 of Set 1 | Kalemie
# Processing Record  460 of Set 1 | Wiang Sa
# Processing Record  461 of Set 1 | Sinnamary
# Processing Record  462 of Set 1 | Troitsko-Pechorsk
# Processing Record  463 of Set 1 | Krasnosel'kup
# Processing Record  464 of Set 1 | Lingao
# Processing Record  465 of Set 1 | Uzunovo
# Processing Record  466 of Set 1 | Acapulco de Juárez
# Processing Record  467 of Set 1 | Bhīmunipatnam
# Processing Record  468 of Set 1 | Assaí
# Processing Record  469 of Set 1 | Sinjār
# Processing Record  470 of Set 1 | Neiafu
# Processing Record  471 of Set 1 | São Mateus
# Processing Record  472 of Set 1 | Bonthe
# Processing Record  473 of Set 1 | Rizhao
# Processing Record  474 of Set 1 | Hūn
# Processing Record  475 of Set 1 | Trelew
# Processing Record  476 of Set 1 | Bambari
# Processing Record  477 of Set 1 | Anjozorobe
# Processing Record  478 of Set 1 | Arecibo
# Processing Record  479 of Set 1 | Ridgecrest
# Processing Record  480 of Set 1 | Emerald
# Processing Record  481 of Set 1 | Biltine
# Processing Record  482 of Set 1 | Iwaki
# Processing Record  483 of Set 1 | Kirkuk
# Processing Record  484 of Set 1 | Lodeynoye Pole
# Processing Record  485 of Set 1 | Caxito
# Processing Record  486 of Set 1 | Troy
# Processing Record  487 of Set 1 | Menongue
# Processing Record  488 of Set 1 | Wana
# Processing Record  489 of Set 1 | Rabo de Peixe
# Processing Record  490 of Set 1 | Juazeiro
# Processing Record  491 of Set 1 | Isiro
# Processing Record  492 of Set 1 | Caarapó
# Processing Record  493 of Set 1 | Brownwood
# Processing Record  494 of Set 1 | Aketi
# Processing Record  495 of Set 1 | Dezhou
# Processing Record  496 of Set 1 | Krasnovishersk
# Processing Record  497 of Set 1 | Vestmannaeyjar
# Processing Record  498 of Set 1 | Hwange
# Processing Record  499 of Set 1 | Boali
# Processing Record  500 of Set 1 | Saint-Augustin
# Processing Record  501 of Set 1 | Aitape
# Processing Record  502 of Set 1 | Bay City
# Processing Record  503 of Set 1 | Nicosia
# Processing Record  504 of Set 1 | Udachny
# Processing Record  505 of Set 1 | Camacha
# Processing Record  506 of Set 1 | Cayenne
# Processing Record  507 of Set 1 | Beloha
# Processing Record  508 of Set 1 | Luwuk
# Processing Record  509 of Set 1 | Saravena
# Processing Record  510 of Set 1 | Mutuípe
# Processing Record  511 of Set 1 | Medina
# Processing Record  512 of Set 1 | Bama
# Processing Record  513 of Set 1 | Barra de Tecoanapa
# Processing Record  514 of Set 1 | Kamogawa
# Processing Record  515 of Set 1 | Digha
# Processing Record  516 of Set 1 | Itaituba
# Processing Record  517 of Set 1 | Puerto Carreño
# Processing Record  518 of Set 1 | Batagay
# Processing Record  519 of Set 1 | Mirny
# Processing Record  520 of Set 1 | Dickinson
# Processing Record  521 of Set 1 | Lorengau
# Processing Record  522 of Set 1 | Shirpur
# Processing Record  523 of Set 1 | Kulykiv
# Processing Record  524 of Set 1 | Port Blair
# Processing Record  525 of Set 1 | Wanaka
# Processing Record  526 of Set 1 | Biak
# Processing Record  527 of Set 1 | Presidencia Roque Sáenz Peña
# Processing Record  528 of Set 1 | Chinhoyi
# Processing Record  529 of Set 1 | Toccoa
# Processing Record  530 of Set 1 | St. George's
# Processing Record  531 of Set 1 | Tateyama
# Processing Record  532 of Set 1 | Haines Junction
# Processing Record  533 of Set 1 | Traverse City
# Processing Record  534 of Set 1 | Mount Gambier
# Processing Record  535 of Set 1 | Rebrikha
# Processing Record  536 of Set 1 | Falam
# Processing Record  537 of Set 1 | Puerto Padre
# Processing Record  538 of Set 1 | Kamisu
# Processing Record  539 of Set 1 | Buraidah
# Processing Record  540 of Set 1 | Bloomfield
# Processing Record  541 of Set 1 | Lufilufi
# Processing Record  542 of Set 1 | Pokosnoye
# Processing Record  543 of Set 1 | Miraflores
# Processing Record  544 of Set 1 | Kloulklubed
# Processing Record  545 of Set 1 | Belogorsk
# Processing Record  546 of Set 1 | Amapá
# Processing Record  547 of Set 1 | Davila
# Processing Record  548 of Set 1 | Praia
# Processing Record  549 of Set 1 | Sumbe
# Processing Record  550 of Set 1 | Dawson Creek
# Processing Record  551 of Set 1 | Lere
# Processing Record  552 of Set 1 | Dargaville
# Processing Record  553 of Set 1 | Santiago de Cao
# Processing Record  554 of Set 1 | Murdochville
# Processing Record  555 of Set 1 | Kattivākkam
# Processing Record  556 of Set 1 | Chetwayi
# Processing Record  557 of Set 1 | Natal
# Processing Record  558 of Set 1 | Jacareacanga
# Processing Record  559 of Set 1 | Lakatoro
# Processing Record  560 of Set 1 | Sri Aman
# Processing Record  561 of Set 1 | Sabha
# Processing Record  562 of Set 1 | San Borja
# Processing Record  563 of Set 1 | Champerico
# Processing Record  564 of Set 1 | Nuuk
# Processing Record  565 of Set 1 | Felanitx
# Processing Record  566 of Set 1 | Marabu
# Processing Record  567 of Set 1 | Inverell
# Processing Record  568 of Set 1 | Moussoro
# Processing Record  569 of Set 1 | Kidal
# Processing Record  570 of Set 1 | Panguna
# Processing Record  571 of Set 1 | Charlottetown
# Processing Record  572 of Set 1 | Kisanga
# Processing Record  573 of Set 1 | Boa Vista
# Processing Record  574 of Set 1 | Cabedelo
# Processing Record  575 of Set 1 | Kenai
# Processing Record  576 of Set 1 | Aksu
# Processing Record  577 of Set 1 | Chokwé
# Processing Record  578 of Set 1 | Koumac
# Processing Record  579 of Set 1 | Nanyang
# Processing Record  580 of Set 1 | Arnedo
# Processing Record  581 of Set 1 | Andrews
# Processing Record  582 of Set 1 | Jingdezhen

# %%
weather_dict = {
    'City': new_city,
    'Latitude': lat,
    'Longitude': long,
    'Max Temp': maxtemp,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind Speed': wind_speed,
    'Country': country
}
weather_data = pd.DataFrame(weather_dict)
weather_data
weather_data.to_csv(r'output.csv', index = False)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data
# Out:
#                City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           Iqaluit   63.7506   -68.5145     21.20        86          75
# 1           Salalah   17.0151    54.0924     68.00        68           0
# 2           Qaanaaq   77.4840   -69.3632     -1.25        79         100
# 3    Guerrero Negro   27.9769  -114.0611     59.83        71           0
# 4           Ushuaia  -54.8000   -68.3000     46.40        76          40
# ..              ...       ...        ...       ...       ...         ...
# 577          Koumac  -20.5667   164.2833     82.89        65          22
# 578         Nanyang   32.9947   112.5328     53.01        38         100
# 579          Arnedo   42.2167    -2.1000     50.00        87           0
# 580         Andrews   32.3187  -102.5457     50.00        29           1
# 581      Jingdezhen   29.2947   117.2079     59.81        68           0
#
#      Wind Speed Country
# 0         18.41      CA
# 1          3.44      OM
# 2          7.56      GL
# 3         15.30      MX
# 4         27.63      AR
# ..          ...     ...
# 577        6.78      NC
# 578        7.70      CN
# 579       11.50      ES
# 580        5.75      US
# 581        0.72      CN
#
# [582 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new = weather_data.loc[weather_data['Humidity'] > 100]
new
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
# Splitting into Northern/Southern Hemi

northern_hemi = weather_data.loc[weather_data['Latitude'] >= 0]
northern_hemi
# Out:
#                City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           Iqaluit   63.7506   -68.5145     21.20        86          75
# 1           Salalah   17.0151    54.0924     68.00        68           0
# 2           Qaanaaq   77.4840   -69.3632     -1.25        79         100
# 3    Guerrero Negro   27.9769  -114.0611     59.83        71           0
# 9          Khatanga   71.9667   102.5000    -34.82        78           5
# ..              ...       ...        ...       ...       ...         ...
# 575            Aksu   41.1231    80.2644     29.46        79          64
# 578         Nanyang   32.9947   112.5328     53.01        38         100
# 579          Arnedo   42.2167    -2.1000     50.00        87           0
# 580         Andrews   32.3187  -102.5457     50.00        29           1
# 581      Jingdezhen   29.2947   117.2079     59.81        68           0
#
#      Wind Speed Country
# 0         18.41      CA
# 1          3.44      OM
# 2          7.56      GL
# 3         15.30      MX
# 9          6.29      RU
# ..          ...     ...
# 575        2.84      CN
# 578        7.70      CN
# 579       11.50      ES
# 580        5.75      US
# 581        0.72      CN
#
# [389 rows x 8 columns]

# %%
southern_hemi = weather_data.loc[weather_data['Latitude'] < 0]
southern_hemi
# Out:
#          City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 4     Ushuaia  -54.8000   -68.3000     46.40        76          40
# 5    Santa Fe  -31.6333   -60.7000     68.86        47           0
# 6      Atuona   -9.8000  -139.0333     79.57        81          74
# 7     Isangel  -19.5500   169.2667     87.80        66          20
# 8     Rikitea  -23.1203  -134.9692     78.30        72          21
# ..        ...       ...        ...       ...       ...         ...
# 569   Panguna   -6.3164   155.4848     84.60        57          18
# 571   Kisanga   -7.4362    37.7034     71.74        88           0
# 573  Cabedelo   -6.9811   -34.8339     78.80        83           0
# 576    Chokwé  -24.5333    32.9833     74.52        92          96
# 577    Koumac  -20.5667   164.2833     82.89        65          22
#
#      Wind Speed Country
# 4         27.63      AR
# 5          5.95      AR
# 6         18.79      PF
# 7          3.44      VU
# 8         13.47      PF
# ..          ...     ...
# 569        3.44      PG
# 571        0.96      TZ
# 573        4.61      BR
# 576        5.86      MZ
# 577        6.78      NC
#
# [193 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Max Temp'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Humidity'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Cloudiness'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Wind Speed'], marker="o", facecolors="red", edgecolors="black")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Max Temp'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.751977417632943

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Max Temp'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.2683754196785143

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Humidity'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.10331429321720025

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Humidity'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.05813342755243068

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Cloudiness'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.14350782183097127

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Cloudiness'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.07027867639124777

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Wind Speed'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.02397568305471929

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Wind Speed'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.052422043579132785
