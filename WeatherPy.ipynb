# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
# Import API key
from api_keys import weather_api_key
import seaborn as sns

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Making sure the units are imperial and settings up the url for the api
units = 'imperial'
url = "http://api.openweathermap.org/data/2.5/weather?"    
# Creating lists for the data that will be stored from the .json request
lat = []
long = []
maxtemp = []
humidity = []
clouds = []
wind_speed = []
country = []
new_city = []
counter = 1

# %%
# Creating a for loop which will query the api and grab info for the set of lats/lngs from above.
# Also for any lat/lng that it doesn't find a city, it will skip over those and go to the next.
for city in cities:
    query_url = f'{url}appid={weather_api_key}&units={units}&q={city}'
    data = requests.get(query_url)
    data2 = data.json()
    if counter == 1:
        print('Beginning Data Retrieval:\n---------------------------')
    try: 
        new_city.append(data2['name'])
        lat.append(data2['coord']['lat'])
        long.append(data2['coord']['lon'])
        maxtemp.append(data2['main']['temp_max'])
        humidity.append(data2['main']['humidity'])
        clouds.append(data2['clouds']['all'])
        wind_speed.append(data2['wind']['speed'])
        country.append(data2['sys']['country'])
        current_city = data2['name']
        print(f'Processing Record  {counter} of Set 1 | {current_city}')
        counter += 1
    except:
        pass
# Out:
# Beginning Data Retrieval:
# ---------------------------
# Processing Record  1 of Set 1 | Asău
# Processing Record  2 of Set 1 | Yerbogachën
# Processing Record  3 of Set 1 | Hongjiang
# Processing Record  4 of Set 1 | Jiazi
# Processing Record  5 of Set 1 | Rikitea
# Processing Record  6 of Set 1 | Amga
# Processing Record  7 of Set 1 | Hobart
# Processing Record  8 of Set 1 | Torbay
# Processing Record  9 of Set 1 | San Policarpo
# Processing Record  10 of Set 1 | Bredasdorp
# Processing Record  11 of Set 1 | Nanortalik
# Processing Record  12 of Set 1 | Nagapattinam
# Processing Record  13 of Set 1 | Maun
# Processing Record  14 of Set 1 | Bubaque
# Processing Record  15 of Set 1 | Manaure
# Processing Record  16 of Set 1 | Puerto Ayora
# Processing Record  17 of Set 1 | Busselton
# Processing Record  18 of Set 1 | Ushuaia
# Processing Record  19 of Set 1 | Airai
# Processing Record  20 of Set 1 | Jamestown
# Processing Record  21 of Set 1 | Mataura
# Processing Record  22 of Set 1 | Sur
# Processing Record  23 of Set 1 | Aklavik
# Processing Record  24 of Set 1 | Rawson
# Processing Record  25 of Set 1 | Rock Sound
# Processing Record  26 of Set 1 | Padang
# Processing Record  27 of Set 1 | Tevaitoa
# Processing Record  28 of Set 1 | Abalak
# Processing Record  29 of Set 1 | Butaritari
# Processing Record  30 of Set 1 | San Cristobal
# Processing Record  31 of Set 1 | Hong Kong
# Processing Record  32 of Set 1 | Baykit
# Processing Record  33 of Set 1 | Tiksi
# Processing Record  34 of Set 1 | Clyde River
# Processing Record  35 of Set 1 | Bridlington
# Processing Record  36 of Set 1 | Uvinza
# Processing Record  37 of Set 1 | Álamos
# Processing Record  38 of Set 1 | Puerto Madryn
# Processing Record  39 of Set 1 | New Norfolk
# Processing Record  40 of Set 1 | Meridian
# Processing Record  41 of Set 1 | Richards Bay
# Processing Record  42 of Set 1 | George Town
# Processing Record  43 of Set 1 | Mbini
# Processing Record  44 of Set 1 | Walvis Bay
# Processing Record  45 of Set 1 | Mount Hagen
# Processing Record  46 of Set 1 | Ostrovnoy
# Processing Record  47 of Set 1 | Amapá
# Processing Record  48 of Set 1 | Esperance
# Processing Record  49 of Set 1 | Kaitangata
# Processing Record  50 of Set 1 | Hambantota
# Processing Record  51 of Set 1 | Nome
# Processing Record  52 of Set 1 | Rome
# Processing Record  53 of Set 1 | East London
# Processing Record  54 of Set 1 | Les Cayes
# Processing Record  55 of Set 1 | Hilo
# Processing Record  56 of Set 1 | Ust-Nera
# Processing Record  57 of Set 1 | Ji’an
# Processing Record  58 of Set 1 | Dingle
# Processing Record  59 of Set 1 | Tuktoyaktuk
# Processing Record  60 of Set 1 | Bluff
# Processing Record  61 of Set 1 | Hithadhoo
# Processing Record  62 of Set 1 | Port Elizabeth
# Processing Record  63 of Set 1 | Grindavik
# Processing Record  64 of Set 1 | Castro
# Processing Record  65 of Set 1 | Blagoyevo
# Processing Record  66 of Set 1 | Luganville
# Processing Record  67 of Set 1 | Namatanai
# Processing Record  68 of Set 1 | Narsaq
# Processing Record  69 of Set 1 | Coquimbo
# Processing Record  70 of Set 1 | Upernavik
# Processing Record  71 of Set 1 | Pavino
# Processing Record  72 of Set 1 | Carnarvon
# Processing Record  73 of Set 1 | Henties Bay
# Processing Record  74 of Set 1 | Bengkulu
# Processing Record  75 of Set 1 | Saldanha
# Processing Record  76 of Set 1 | Souillac
# Processing Record  77 of Set 1 | Caravelas
# Processing Record  78 of Set 1 | Lompoc
# Processing Record  79 of Set 1 | Tashtyp
# Processing Record  80 of Set 1 | Flinders
# Processing Record  81 of Set 1 | Nikolskoye
# Processing Record  82 of Set 1 | Mbandaka
# Processing Record  83 of Set 1 | Arman'
# Processing Record  84 of Set 1 | Portland
# Processing Record  85 of Set 1 | Sittwe
# Processing Record  86 of Set 1 | Vitim
# Processing Record  87 of Set 1 | Erzin
# Processing Record  88 of Set 1 | Saint Paul Harbor
# Processing Record  89 of Set 1 | Punta Arenas
# Processing Record  90 of Set 1 | Camopi
# Processing Record  91 of Set 1 | Leningradskiy
# Processing Record  92 of Set 1 | Coyhaique
# Processing Record  93 of Set 1 | Cape Town
# Processing Record  94 of Set 1 | Shimanovsk
# Processing Record  95 of Set 1 | Gazli
# Processing Record  96 of Set 1 | Kushiro
# Processing Record  97 of Set 1 | Cabo San Lucas
# Processing Record  98 of Set 1 | Swellendam
# Processing Record  99 of Set 1 | Vaini
# Processing Record  100 of Set 1 | Bridgewater
# Processing Record  101 of Set 1 | Albany
# Processing Record  102 of Set 1 | Kapaa
# Processing Record  103 of Set 1 | Saint Anthony
# Processing Record  104 of Set 1 | Palmer
# Processing Record  105 of Set 1 | Tual
# Processing Record  106 of Set 1 | Pacific Grove
# Processing Record  107 of Set 1 | Tasiilaq
# Processing Record  108 of Set 1 | Mareeba
# Processing Record  109 of Set 1 | Hermanus
# Processing Record  110 of Set 1 | Karīmpur
# Processing Record  111 of Set 1 | Constitución
# Processing Record  112 of Set 1 | Ţahţā
# Processing Record  113 of Set 1 | Tonantins
# Processing Record  114 of Set 1 | Niamey
# Processing Record  115 of Set 1 | Warsaw
# Processing Record  116 of Set 1 | Szydłowiec
# Processing Record  117 of Set 1 | Opuwo
# Processing Record  118 of Set 1 | Bethel
# Processing Record  119 of Set 1 | Atuona
# Processing Record  120 of Set 1 | Port Lincoln
# Processing Record  121 of Set 1 | Cherskiy
# Processing Record  122 of Set 1 | Arraial do Cabo
# Processing Record  123 of Set 1 | Epe
# Processing Record  124 of Set 1 | Boa Vista
# Processing Record  125 of Set 1 | Avarua
# Processing Record  126 of Set 1 | Moyale
# Processing Record  127 of Set 1 | Dunedin
# Processing Record  128 of Set 1 | Thompson
# Processing Record  129 of Set 1 | Kirando
# Processing Record  130 of Set 1 | Barra de Tecoanapa
# Processing Record  131 of Set 1 | Taseyevo
# Processing Record  132 of Set 1 | Caucayá
# Processing Record  133 of Set 1 | Ambo
# Processing Record  134 of Set 1 | Mafinga
# Processing Record  135 of Set 1 | Hervey Bay
# Processing Record  136 of Set 1 | Banepā
# Processing Record  137 of Set 1 | Ribeira Grande
# Processing Record  138 of Set 1 | Muzhi
# Processing Record  139 of Set 1 | Kidal
# Processing Record  140 of Set 1 | Barrow
# Processing Record  141 of Set 1 | Salalah
# Processing Record  142 of Set 1 | Kuah
# Processing Record  143 of Set 1 | Qaanaaq
# Processing Record  144 of Set 1 | Vila Franca do Campo
# Processing Record  145 of Set 1 | Saint George
# Processing Record  146 of Set 1 | Dikson
# Processing Record  147 of Set 1 | Rio Grande
# Processing Record  148 of Set 1 | Bo Rai
# Processing Record  149 of Set 1 | Panabá
# Processing Record  150 of Set 1 | Chittarkonda
# Processing Record  151 of Set 1 | Yenagoa
# Processing Record  152 of Set 1 | Kiryat Gat
# Processing Record  153 of Set 1 | Saskylakh
# Processing Record  154 of Set 1 | Twentynine Palms
# Processing Record  155 of Set 1 | Pringsewu
# Processing Record  156 of Set 1 | Lethem
# Processing Record  157 of Set 1 | Liepāja
# Processing Record  158 of Set 1 | Yumen
# Processing Record  159 of Set 1 | Mezen'
# Processing Record  160 of Set 1 | Neyshabur
# Processing Record  161 of Set 1 | Jalu
# Processing Record  162 of Set 1 | Dongsheng
# Processing Record  163 of Set 1 | Norman Wells
# Processing Record  164 of Set 1 | Rosarito
# Processing Record  165 of Set 1 | Bilma
# Processing Record  166 of Set 1 | Suntar
# Processing Record  167 of Set 1 | Todos Santos
# Processing Record  168 of Set 1 | Zhezkazgan
# Processing Record  169 of Set 1 | São João da Barra
# Processing Record  170 of Set 1 | Guane
# Processing Record  171 of Set 1 | Chui
# Processing Record  172 of Set 1 | Río Gallegos
# Processing Record  173 of Set 1 | Frontera
# Processing Record  174 of Set 1 | Nyurba
# Processing Record  175 of Set 1 | Sabancuy
# Processing Record  176 of Set 1 | San Quintín
# Processing Record  177 of Set 1 | Birin
# Processing Record  178 of Set 1 | Ternate
# Processing Record  179 of Set 1 | Ahipara
# Processing Record  180 of Set 1 | Ouallam
# Processing Record  181 of Set 1 | Kiunga
# Processing Record  182 of Set 1 | Biak
# Processing Record  183 of Set 1 | Marang
# Processing Record  184 of Set 1 | Pevek
# Processing Record  185 of Set 1 | Pallāvaram
# Processing Record  186 of Set 1 | Ugoofaaru
# Processing Record  187 of Set 1 | Matara
# Processing Record  188 of Set 1 | Iranshahr
# Processing Record  189 of Set 1 | Ancud
# Processing Record  190 of Set 1 | Ossora
# Processing Record  191 of Set 1 | Saint-Philippe
# Processing Record  192 of Set 1 | Avilés
# Processing Record  193 of Set 1 | Fare
# Processing Record  194 of Set 1 | Dosso
# Processing Record  195 of Set 1 | Kuteynykove
# Processing Record  196 of Set 1 | Pekan
# Processing Record  197 of Set 1 | Husavik
# Processing Record  198 of Set 1 | Villa Carlos Paz
# Processing Record  199 of Set 1 | Dzerzhinskoye
# Processing Record  200 of Set 1 | Ilulissat
# Processing Record  201 of Set 1 | São Filipe
# Processing Record  202 of Set 1 | Tromsø
# Processing Record  203 of Set 1 | Port Alfred
# Processing Record  204 of Set 1 | Tacuarembó
# Processing Record  205 of Set 1 | Geraldton
# Processing Record  206 of Set 1 | Mahébourg
# Processing Record  207 of Set 1 | Havre-St-Pierre
# Processing Record  208 of Set 1 | Kavaratti
# Processing Record  209 of Set 1 | Mar del Plata
# Processing Record  210 of Set 1 | Havelock
# Processing Record  211 of Set 1 | Ola
# Processing Record  212 of Set 1 | Kostanay
# Processing Record  213 of Set 1 | The Valley
# Processing Record  214 of Set 1 | Acapulco de Juárez
# Processing Record  215 of Set 1 | Evensk
# Processing Record  216 of Set 1 | Bījār
# Processing Record  217 of Set 1 | Kahului
# Processing Record  218 of Set 1 | Kutum
# Processing Record  219 of Set 1 | Russell
# Processing Record  220 of Set 1 | Poum
# Processing Record  221 of Set 1 | Atar
# Processing Record  222 of Set 1 | Vestmannaeyjar
# Processing Record  223 of Set 1 | Yellowknife
# Processing Record  224 of Set 1 | Dryden
# Processing Record  225 of Set 1 | Stromness
# Processing Record  226 of Set 1 | Kavieng
# Processing Record  227 of Set 1 | Bossangoa
# Processing Record  228 of Set 1 | Lakes Entrance
# Processing Record  229 of Set 1 | Vangaindrano
# Processing Record  230 of Set 1 | Magadan
# Processing Record  231 of Set 1 | Yar-Sale
# Processing Record  232 of Set 1 | Cumaral
# Processing Record  233 of Set 1 | Usinsk
# Processing Record  234 of Set 1 | Kirakira
# Processing Record  235 of Set 1 | Uribia
# Processing Record  236 of Set 1 | Lavrentiya
# Processing Record  237 of Set 1 | Yondó
# Processing Record  238 of Set 1 | Ayan
# Processing Record  239 of Set 1 | Jinchang
# Processing Record  240 of Set 1 | Suez
# Processing Record  241 of Set 1 | Severo-Kuril'sk
# Processing Record  242 of Set 1 | Hollola
# Processing Record  243 of Set 1 | Kuala Terengganu
# Processing Record  244 of Set 1 | Victor Harbor
# Processing Record  245 of Set 1 | Heihe
# Processing Record  246 of Set 1 | Xining
# Processing Record  247 of Set 1 | Tucuruí
# Processing Record  248 of Set 1 | Verkhnyaya Balkariya
# Processing Record  249 of Set 1 | Ipirá
# Processing Record  250 of Set 1 | Klaksvík
# Processing Record  251 of Set 1 | Sitka
# Processing Record  252 of Set 1 | Beira
# Processing Record  253 of Set 1 | Natal
# Processing Record  254 of Set 1 | Thinadhoo
# Processing Record  255 of Set 1 | Katsuura
# Processing Record  256 of Set 1 | Eilat
# Processing Record  257 of Set 1 | Adrar
# Processing Record  258 of Set 1 | Te Anau
# Processing Record  259 of Set 1 | Nacala
# Processing Record  260 of Set 1 | Grand Gaube
# Processing Record  261 of Set 1 | Ponta do Sol
# Processing Record  262 of Set 1 | Comodoro Rivadavia
# Processing Record  263 of Set 1 | Longyearbyen
# Processing Record  264 of Set 1 | Yinchuan
# Processing Record  265 of Set 1 | Nishihara
# Processing Record  266 of Set 1 | Hasaki
# Processing Record  267 of Set 1 | Tukan
# Processing Record  268 of Set 1 | Alofi
# Processing Record  269 of Set 1 | Masvingo
# Processing Record  270 of Set 1 | Pacaembu
# Processing Record  271 of Set 1 | Bereda
# Processing Record  272 of Set 1 | Khatanga
# Processing Record  273 of Set 1 | Yong’an
# Processing Record  274 of Set 1 | Sehithwa
# Processing Record  275 of Set 1 | Morro Bay
# Processing Record  276 of Set 1 | Bairiki Village
# Processing Record  277 of Set 1 | Kalāleh
# Processing Record  278 of Set 1 | Rafai
# Processing Record  279 of Set 1 | Alta Floresta
# Processing Record  280 of Set 1 | Okha
# Processing Record  281 of Set 1 | Launceston
# Processing Record  282 of Set 1 | Naze
# Processing Record  283 of Set 1 | Tezu
# Processing Record  284 of Set 1 | Pilar do Sul
# Processing Record  285 of Set 1 | Beringovskiy
# Processing Record  286 of Set 1 | ‘Āhuimanu
# Processing Record  287 of Set 1 | Ierapetra
# Processing Record  288 of Set 1 | Sahuaripa
# Processing Record  289 of Set 1 | Digby
# Processing Record  290 of Set 1 | Yur’yevets
# Processing Record  291 of Set 1 | Mount Gambier
# Processing Record  292 of Set 1 | Mombetsu
# Processing Record  293 of Set 1 | Iqaluit
# Processing Record  294 of Set 1 | Kumul
# Processing Record  295 of Set 1 | Cidreira
# Processing Record  296 of Set 1 | Arrondissement de Saint-Claude
# Processing Record  297 of Set 1 | Fomboni
# Processing Record  298 of Set 1 | Prainha
# Processing Record  299 of Set 1 | Mariehamn
# Processing Record  300 of Set 1 | Maxixe
# Processing Record  301 of Set 1 | Am Timan
# Processing Record  302 of Set 1 | Bandarbeyla
# Processing Record  303 of Set 1 | General Roca
# Processing Record  304 of Set 1 | Solwezi
# Processing Record  305 of Set 1 | Tautira
# Processing Record  306 of Set 1 | Vardø
# Processing Record  307 of Set 1 | Havøysund
# Processing Record  308 of Set 1 | Villa Guerrero
# Processing Record  309 of Set 1 | Bonthe
# Processing Record  310 of Set 1 | Huarmey
# Processing Record  311 of Set 1 | Plácido de Castro
# Processing Record  312 of Set 1 | Papara
# Processing Record  313 of Set 1 | Fukuechō
# Processing Record  314 of Set 1 | Kalmunai
# Processing Record  315 of Set 1 | Taksimo
# Processing Record  316 of Set 1 | Itatiaia
# Processing Record  317 of Set 1 | Fairbanks
# Processing Record  318 of Set 1 | Zimmi
# Processing Record  319 of Set 1 | Port Antonio
# Processing Record  320 of Set 1 | Eskişehir
# Processing Record  321 of Set 1 | Mayumba
# Processing Record  322 of Set 1 | Road Town
# Processing Record  323 of Set 1 | La Goulette
# Processing Record  324 of Set 1 | Kigoma
# Processing Record  325 of Set 1 | Jahāzpur
# Processing Record  326 of Set 1 | Rāvar
# Processing Record  327 of Set 1 | Narasannapeta
# Processing Record  328 of Set 1 | Piterka
# Processing Record  329 of Set 1 | Qaqortoq
# Processing Record  330 of Set 1 | Micheweni
# Processing Record  331 of Set 1 | Alexandria
# Processing Record  332 of Set 1 | Copiapó
# Processing Record  333 of Set 1 | Cockburn Town
# Processing Record  334 of Set 1 | Port Hawkesbury
# Processing Record  335 of Set 1 | Codrington
# Processing Record  336 of Set 1 | Stepnyak
# Processing Record  337 of Set 1 | Bambous Virieux
# Processing Record  338 of Set 1 | Wahiawā
# Processing Record  339 of Set 1 | Picos
# Processing Record  340 of Set 1 | Najrān
# Processing Record  341 of Set 1 | Bonavista
# Processing Record  342 of Set 1 | Lebu
# Processing Record  343 of Set 1 | North Bend
# Processing Record  344 of Set 1 | Half Moon Bay
# Processing Record  345 of Set 1 | Mporokoso
# Processing Record  346 of Set 1 | Ilo
# Processing Record  347 of Set 1 | Melton
# Processing Record  348 of Set 1 | Bathsheba
# Processing Record  349 of Set 1 | Gizo Government Station
# Processing Record  350 of Set 1 | Hobyo
# Processing Record  351 of Set 1 | Manaus
# Processing Record  352 of Set 1 | College
# Processing Record  353 of Set 1 | Rauma
# Processing Record  354 of Set 1 | Honiara
# Processing Record  355 of Set 1 | Labuhan
# Processing Record  356 of Set 1 | Port Augusta
# Processing Record  357 of Set 1 | Tsurib
# Processing Record  358 of Set 1 | Boddam
# Processing Record  359 of Set 1 | Meulaboh
# Processing Record  360 of Set 1 | Tateyama
# Processing Record  361 of Set 1 | Samarai
# Processing Record  362 of Set 1 | Phan Thiet
# Processing Record  363 of Set 1 | Gobabis
# Processing Record  364 of Set 1 | Ballina
# Processing Record  365 of Set 1 | Lensk
# Processing Record  366 of Set 1 | Cayenne
# Processing Record  367 of Set 1 | Al Bardīyah
# Processing Record  368 of Set 1 | Jatai
# Processing Record  369 of Set 1 | Bontang
# Processing Record  370 of Set 1 | San Patricio
# Processing Record  371 of Set 1 | Léo
# Processing Record  372 of Set 1 | Atambua
# Processing Record  373 of Set 1 | Kommunar
# Processing Record  374 of Set 1 | Foz do Iguaçu
# Processing Record  375 of Set 1 | Laguna
# Processing Record  376 of Set 1 | Tuatapere
# Processing Record  377 of Set 1 | Filingué
# Processing Record  378 of Set 1 | Chokurdakh
# Processing Record  379 of Set 1 | Bac Lieu
# Processing Record  380 of Set 1 | Hay River
# Processing Record  381 of Set 1 | Rodrigues Alves
# Processing Record  382 of Set 1 | Bella Union
# Processing Record  383 of Set 1 | Krompachy
# Processing Record  384 of Set 1 | Muros
# Processing Record  385 of Set 1 | Oktyabr'skiy
# Processing Record  386 of Set 1 | Novoagansk
# Processing Record  387 of Set 1 | Palora
# Processing Record  388 of Set 1 | Clifton Springs
# Processing Record  389 of Set 1 | Tabou
# Processing Record  390 of Set 1 | Shawnee
# Processing Record  391 of Set 1 | Rincon
# Processing Record  392 of Set 1 | Karratha
# Processing Record  393 of Set 1 | Hamilton
# Processing Record  394 of Set 1 | Sungai Penuh
# Processing Record  395 of Set 1 | Santa Luzia
# Processing Record  396 of Set 1 | Kushmurun
# Processing Record  397 of Set 1 | Cururupu
# Processing Record  398 of Set 1 | Berdigestyakh
# Processing Record  399 of Set 1 | Barwāni
# Processing Record  400 of Set 1 | Rāmpura
# Processing Record  401 of Set 1 | Trelew
# Processing Record  402 of Set 1 | Gijang
# Processing Record  403 of Set 1 | Haines Junction
# Processing Record  404 of Set 1 | Gimli
# Processing Record  405 of Set 1 | Awjilah
# Processing Record  406 of Set 1 | Moerai
# Processing Record  407 of Set 1 | Cassano delle Murge
# Processing Record  408 of Set 1 | Inhambane
# Processing Record  409 of Set 1 | Cuencamé de Ceniceros
# Processing Record  410 of Set 1 | Aksarka
# Processing Record  411 of Set 1 | Srednekolymsk
# Processing Record  412 of Set 1 | Omsukchan
# Processing Record  413 of Set 1 | Lorengau
# Processing Record  414 of Set 1 | Vila Velha
# Processing Record  415 of Set 1 | Ibipeba
# Processing Record  416 of Set 1 | Grieskirchen
# Processing Record  417 of Set 1 | Alekseyevsk
# Processing Record  418 of Set 1 | Zigong
# Processing Record  419 of Set 1 | Nardaran
# Processing Record  420 of Set 1 | Liaocheng
# Processing Record  421 of Set 1 | Deputatsky
# Processing Record  422 of Set 1 | Darnah
# Processing Record  423 of Set 1 | Winnemucca
# Processing Record  424 of Set 1 | Petatlán
# Processing Record  425 of Set 1 | Itoman
# Processing Record  426 of Set 1 | Korla
# Processing Record  427 of Set 1 | Rusape
# Processing Record  428 of Set 1 | Mackay
# Processing Record  429 of Set 1 | Guerrero Negro
# Processing Record  430 of Set 1 | Christchurch
# Processing Record  431 of Set 1 | Ligayan
# Processing Record  432 of Set 1 | Cabedelo
# Processing Record  433 of Set 1 | Kruisfontein
# Processing Record  434 of Set 1 | Zhangye
# Processing Record  435 of Set 1 | Margate
# Processing Record  436 of Set 1 | Kawalu
# Processing Record  437 of Set 1 | Iberia
# Processing Record  438 of Set 1 | Laas
# Processing Record  439 of Set 1 | Port-Gentil
# Processing Record  440 of Set 1 | Bani Walid
# Processing Record  441 of Set 1 | Provideniya
# Processing Record  442 of Set 1 | Tha Mai
# Processing Record  443 of Set 1 | Goiatuba
# Processing Record  444 of Set 1 | Mirny
# Processing Record  445 of Set 1 | Charlestown
# Processing Record  446 of Set 1 | Novopokrovskaya
# Processing Record  447 of Set 1 | Tura
# Processing Record  448 of Set 1 | Taywarah
# Processing Record  449 of Set 1 | Vao
# Processing Record  450 of Set 1 | Tsumeb
# Processing Record  451 of Set 1 | Lüderitz
# Processing Record  452 of Set 1 | Uruaçu
# Processing Record  453 of Set 1 | Slave Lake
# Processing Record  454 of Set 1 | Kāgal
# Processing Record  455 of Set 1 | Guebwiller
# Processing Record  456 of Set 1 | Isangel
# Processing Record  457 of Set 1 | Liwale
# Processing Record  458 of Set 1 | Kemijärvi
# Processing Record  459 of Set 1 | Castro Daire
# Processing Record  460 of Set 1 | Nouadhibou
# Processing Record  461 of Set 1 | Saint-Pierre
# Processing Record  462 of Set 1 | Boguchany
# Processing Record  463 of Set 1 | Pangnirtung
# Processing Record  464 of Set 1 | Turukhansk
# Processing Record  465 of Set 1 | Guarapari
# Processing Record  466 of Set 1 | Elgin
# Processing Record  467 of Set 1 | Nemuro
# Processing Record  468 of Set 1 | Médéa
# Processing Record  469 of Set 1 | Shimoda
# Processing Record  470 of Set 1 | Umeå
# Processing Record  471 of Set 1 | Morrinhos
# Processing Record  472 of Set 1 | Yulara
# Processing Record  473 of Set 1 | Durrës
# Processing Record  474 of Set 1 | Oeiras
# Processing Record  475 of Set 1 | Galle
# Processing Record  476 of Set 1 | Bilāsipāra
# Processing Record  477 of Set 1 | Naryan-Mar
# Processing Record  478 of Set 1 | Puerto Carreño
# Processing Record  479 of Set 1 | Rampur Hat
# Processing Record  480 of Set 1 | Mayor Pablo Lagerenza
# Processing Record  481 of Set 1 | Kyzyl-Suu
# Processing Record  482 of Set 1 | Soe
# Processing Record  483 of Set 1 | Kibakwe
# Processing Record  484 of Set 1 | Wawa
# Processing Record  485 of Set 1 | Progreso
# Processing Record  486 of Set 1 | Ozinki
# Processing Record  487 of Set 1 | Belmonte
# Processing Record  488 of Set 1 | San Gabriel Tetzoyocán
# Processing Record  489 of Set 1 | Nchelenge
# Processing Record  490 of Set 1 | Tigzirt
# Processing Record  491 of Set 1 | Boyolangu
# Processing Record  492 of Set 1 | Fortuna
# Processing Record  493 of Set 1 | Borogontsy
# Processing Record  494 of Set 1 | Krasnyy Chikoy
# Processing Record  495 of Set 1 | Tadine
# Processing Record  496 of Set 1 | Prome
# Processing Record  497 of Set 1 | Düzce
# Processing Record  498 of Set 1 | Sambava
# Processing Record  499 of Set 1 | Yendi
# Processing Record  500 of Set 1 | Chifeng
# Processing Record  501 of Set 1 | Miraflores
# Processing Record  502 of Set 1 | Chukhloma
# Processing Record  503 of Set 1 | Bousso
# Processing Record  504 of Set 1 | El Dorado
# Processing Record  505 of Set 1 | Faya
# Processing Record  506 of Set 1 | Ashtian
# Processing Record  507 of Set 1 | Port Hedland
# Processing Record  508 of Set 1 | Los Llanos de Aridane
# Processing Record  509 of Set 1 | Weligama
# Processing Record  510 of Set 1 | Mendrisio
# Processing Record  511 of Set 1 | Dehlorān
# Processing Record  512 of Set 1 | Beisfjord
# Processing Record  513 of Set 1 | Yeppoon
# Processing Record  514 of Set 1 | La Ronge
# Processing Record  515 of Set 1 | Gondanglegi
# Processing Record  516 of Set 1 | Novopokrovka
# Processing Record  517 of Set 1 | Shawville
# Processing Record  518 of Set 1 | Bulgan
# Processing Record  519 of Set 1 | Kiruna
# Processing Record  520 of Set 1 | Mayo
# Processing Record  521 of Set 1 | Pandamatenga
# Processing Record  522 of Set 1 | Palm Valley
# Processing Record  523 of Set 1 | Rancho Palos Verdes
# Processing Record  524 of Set 1 | Broome
# Processing Record  525 of Set 1 | Ban Tak
# Processing Record  526 of Set 1 | La Asuncion
# Processing Record  527 of Set 1 | Uchaly
# Processing Record  528 of Set 1 | Corralillo
# Processing Record  529 of Set 1 | Nizhniy Baskunchak
# Processing Record  530 of Set 1 | Omagh
# Processing Record  531 of Set 1 | Orotukan
# Processing Record  532 of Set 1 | Sola
# Processing Record  533 of Set 1 | Vanimo
# Processing Record  534 of Set 1 | Anadyr
# Processing Record  535 of Set 1 | Sars
# Processing Record  536 of Set 1 | Kālīganj
# Processing Record  537 of Set 1 | Machado
# Processing Record  538 of Set 1 | Muroto-misakicho
# Processing Record  539 of Set 1 | Kaduna
# Processing Record  540 of Set 1 | Quatre Cocos
# Processing Record  541 of Set 1 | Inuvik
# Processing Record  542 of Set 1 | Rafsanjān
# Processing Record  543 of Set 1 | Ol'ga
# Processing Record  544 of Set 1 | De Aar
# Processing Record  545 of Set 1 | Olinda
# Processing Record  546 of Set 1 | Tilichiki
# Processing Record  547 of Set 1 | Bilibino
# Processing Record  548 of Set 1 | Agirish
# Processing Record  549 of Set 1 | Petites Anses
# Processing Record  550 of Set 1 | Khandyga
# Processing Record  551 of Set 1 | Keti Bandar
# Processing Record  552 of Set 1 | Beloha
# Processing Record  553 of Set 1 | Vilyuysk
# Processing Record  554 of Set 1 | Manakara
# Processing Record  555 of Set 1 | Uenohara
# Processing Record  556 of Set 1 | Mandalgovi
# Processing Record  557 of Set 1 | Kirovskiy
# Processing Record  558 of Set 1 | Mogadishu
# Processing Record  559 of Set 1 | Lázaro Cárdenas
# Processing Record  560 of Set 1 | Kanashevo
# Processing Record  561 of Set 1 | Kenai
# Processing Record  562 of Set 1 | Mehamn
# Processing Record  563 of Set 1 | Qian’an
# Processing Record  564 of Set 1 | Port Blair
# Processing Record  565 of Set 1 | Fort Nelson
# Processing Record  566 of Set 1 | Tommot

# %%
# Creating the dataframe by putting it first into a dictionary, and then into the dataframe
weather_dict = {
    'City': new_city,
    'Latitude': lat,
    'Longitude': long,
    'Max Temp': maxtemp,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind Speed': wind_speed,
    'Country': country
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Taking the dataframe and storing as a .csv file for use in Vacation.Py
weather_data.to_csv(r'output.csv', index = False)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Displaying the new dataframe!
weather_data
# **** Note: I took the **Max Temp** specifically because that is what was displayed in the starter code walkthrough!
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           Asău   46.4333    26.4000     37.40        93          90
# 1    Yerbogachën   61.2767   108.0108      8.92        93         100
# 2      Hongjiang   27.1100   109.9956     66.51        93          90
# 3          Jiazi   22.8779   116.0670     68.65        81          98
# 4        Rikitea  -23.1203  -134.9692     81.27        71           2
# ..           ...       ...        ...       ...       ...         ...
# 561       Mehamn   71.0357    27.8492     21.20        79          20
# 562      Qian’an   44.9932   124.0581     23.31        37          16
# 563   Port Blair   11.6667    92.7500     78.33        79          74
# 564  Fort Nelson   58.8053  -122.7002     21.20        58          40
# 565       Tommot   58.9564   126.2925     -3.37        90          20
#
#      Wind Speed Country
# 0         10.36      RO
# 1          9.35      RU
# 2          0.11      CN
# 3          3.42      CN
# 4          6.69      PF
# ..          ...     ...
# 561       10.36      NO
# 562       18.50      CN
# 563        6.51      IN
# 564        8.37      CA
# 565        1.81      RU
#
# [566 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Finding out if there are any values in the column "Humidity" that are over 100%
new = weather_data.loc[weather_data['Humidity'] > 100]
new
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
# Splitting into Northern Hemisphere...

northern_hemi = weather_data.loc[weather_data['Latitude'] >= 0]
northern_hemi
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0           Asău   46.4333    26.4000     37.40        93          90
# 1    Yerbogachën   61.2767   108.0108      8.92        93         100
# 2      Hongjiang   27.1100   109.9956     66.51        93          90
# 3          Jiazi   22.8779   116.0670     68.65        81          98
# 5           Amga   60.8953   131.9608     -8.99        94           0
# ..           ...       ...        ...       ...       ...         ...
# 561       Mehamn   71.0357    27.8492     21.20        79          20
# 562      Qian’an   44.9932   124.0581     23.31        37          16
# 563   Port Blair   11.6667    92.7500     78.33        79          74
# 564  Fort Nelson   58.8053  -122.7002     21.20        58          40
# 565       Tommot   58.9564   126.2925     -3.37        90          20
#
#      Wind Speed Country
# 0         10.36      RO
# 1          9.35      RU
# 2          0.11      CN
# 3          3.42      CN
# 5          5.10      RU
# ..          ...     ...
# 561       10.36      NO
# 562       18.50      CN
# 563        6.51      IN
# 564        8.37      CA
# 565        1.81      RU
#
# [383 rows x 8 columns]

# %%
#And southern hemisphere here ->
southern_hemi = weather_data.loc[weather_data['Latitude'] < 0]
southern_hemi
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 4         Rikitea  -23.1203  -134.9692     81.27        71           2
# 6          Hobart  -42.8794   147.3294     57.00        62          75
# 9      Bredasdorp  -34.5322    20.0403     60.80        94           8
# 12           Maun  -19.9833    23.4167     71.60        78           0
# 15   Puerto Ayora   -0.7393   -90.3518     80.60        78          75
# ..            ...       ...        ...       ...       ...         ...
# 539  Quatre Cocos  -20.2078    57.7625     78.80        83          40
# 543        De Aar  -30.6497    24.0123     62.28        71           0
# 544        Olinda   -8.0089   -34.8553     78.80        69          75
# 551        Beloha  -25.1667    45.0500     74.07        78           0
# 553      Manakara  -22.1333    48.0167     74.75        89          55
#
#      Wind Speed Country
# 4          6.69      PF
# 6          8.05      AU
# 9          3.44      ZA
# 12         3.58      BW
# 15        16.11      EC
# ..          ...     ...
# 539        9.22      MU
# 543        6.15      ZA
# 544       10.36      BR
# 551        9.06      MG
# 553        1.39      MG
#
# [183 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
a4_dims = (100,100)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.scatterplot(weather_data['Latitude'], weather_data['Max Temp'], marker="o", palette=cmap, hue=weather_data['Latitude'])
plt.title('Latitude vs Temperature Plot')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('latitude_vs_temp')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6381a93d282b> in <module>
#       1 cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
#       2 a4_dims = (100,100)
# ----> 3 fig, ax = pyplot.subplots(figsize=a4_dims)
#       4 sns.scatterplot(weather_data['Latitude'], weather_data['Max Temp'], marker="o", palette=cmap, hue=weather_data['Latitude'])
#       5 plt.title('Latitude vs Temperature Plot')
#
# NameError: name 'pyplot' is not defined

# %%
# With this temperature plot, it looks as though as the latitude increases, the temperature drops off.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
sns.scatterplot(weather_data['Latitude'], weather_data['Humidity'], marker="o", palette=cmap, hue=weather_data['Latitude'])
plt.title('Latitude vs Humidity Plot')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('latitude_vs_humidity')

# %%
# There isn't much to tell from this data other then there seem to be some clustering in the top left and top right,
# that may indicate there tends to be more humidty the more north and south you go.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
sns.scatterplot(weather_data['Latitude'], weather_data['Cloudiness'], marker="o", palette=cmap,  hue=weather_data['Latitude'])
plt.title('Latitude vs Cloudiness Plot')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('latitude_vs_cloudiness')

# %%
# Again, this one is a bit harder to form conclusions about ,but it looks as though
# a good amount of either full cloudiness or none at all occur at all points along the latitude axis

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
sns.scatterplot(weather_data['Latitude'], weather_data['Wind Speed'], marker="o", palette=cmap, hue=weather_data['Latitude'])
plt.title('Latitude vs Wind Speed Plot')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('latitude_vs_windspeed')

# %%
# With this particular plot, most of the data lies below the 15 mph mark for all the latitudes observed.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Max Temp'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')
plt.title('Max Temp vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_temp_latitude')
# Show plot
plt.show()

# %%
# It looks as though there is a clear trend downward for latitude downward as the max temp increases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Max Temp'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Max Temp')
plt.ylabel('Latitude')
plt.title('Max Temp vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_temp_latitude')
# Show plot
plt.show()

# %%
# Though not as concise a scatter plot as the last one, it looks as though there is a trend upward for latitude downward as the max temp increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Humidity'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')
plt.title('Humidity vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_humidity_latitude')
# Show plot
plt.show()

# %%
# There appears to be a slight increase in humidity as the latitudes increase

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Humidity'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Humidity %')
plt.ylabel('Latitude')
plt.title('Humidity vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_humidity_latitude')
# Show plot
plt.show()

# %%
# Inversely, it looks as though as the latitudes decrease, the humidity increases

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Cloudiness'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')
plt.title('Cloudiness vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_cloudiness_latitude')
# Show plot
plt.show()

# %%
# These next two plots are a bit harder to truly come to a conclusion. It looks as though most of the data
# is clustered on either end of the cloudiness scale (close to 0 and around 100), as shown by the previous
# scatter plot shown above (Latitude vs Cloudiness)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Cloudiness'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Cloudiness %')
plt.ylabel('Latitude')
plt.title('Cloudiness vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_humidity_latitude')
# Show plot
plt.show()

# %%
# The same thing, but a bit less so, as there aren't as many data points, but it also looks as though
# most of the data points are on either end of the cloudiness range

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi['Wind Speed'].astype('float')
y_values = northern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Wind Speed vs Latitude Linear Regression (Northern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('northern_windspeed_latitude')
# Show plot
plt.show()

# %%
# It appears as though most of the data points lie around where the wind speed is < 15 or so. Thus, latitude
# isn't as much a factor here as it is with other plots

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi['Wind Speed'].astype('float')
y_values = southern_hemi['Latitude'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title('Wind Speed vs Latitude Linear Regression (Southern)')
# Print r square value
print(f"R squared: {rvalue**2}")
plt.savefig('southern_windspeed_latitude')
# Show plot
plt.show()

# %%
# This one is a bit more obscure though the linear regression shows a similar relationship; as the latitudes
# get closer to the south pole, the wind speed tends to drop off a bit.
